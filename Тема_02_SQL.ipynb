# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 11 октября 2021 года<br>
# ФРФТ20-2; ФРФТ20-1; ОД/207 (ул. Олеко Дундича, 23)

# %% [markdown]
# # 1. Основные понятия и определения
#
# ## 1.1. Основные понятия реляционных баз данных
#
# Основой современных систем, использующих базы данных, является реляционная модель данных. В этой модели данные, представляющие информацию о предметной области, организованы в виде двумерных таблиц, называемых отношениями.
#
# <img src="./Img/img_01.png">
#
# - Термины отношение и таблица обычно употребляются как синонимы. Верхняя строка таблицы-отношения называется заголовком
# - Строки таблицы-отношения называются кортежами или записями. Столбцы называются атрибутами. Термины атрибут, столбец, колонка, поле обычно используются как синонимы. Каждый атрибут имеет имя, которое должно быть уникальным в конкретной таблице-отношении, однако в разных таблицах имена атрибутов могут совпадать
# - Количество кортежей в таблице-отношении называется кардинальным числом отношения, а количество атрибутов называется степенью отношения
# - Ключ или первичный ключ отношения – это уникальный идентификатор строк (кортежей), то есть такой атрибут (набор атрибутов), для которого в любой момент времени в отношении не существует строк с одинаковыми значениями этого атрибута (набора атрибутов). На приведенном рисунке таблицы ячейка с именем ключевого атрибута имеет нижнюю границу в видед войной черты
# - Домен отношения – это совокупность значений, из которых могут выбираться значения конкретного атрибута
#
# Отношения реляционной базы данных обладают следующими свойствами:
# - в отношениях не должно быть кортежей-дубликатов;
# - кортежи отношений неупорядочены;
# - атрибуты отношений также неупорядочены.
#
# Из уникальности кортежей следует, что в отношении всегда имеется атрибут или набор атрибутов, позволяющий идентифицировать кортеж; другими словами, в отношении всегда есть первичный ключ.
#
# Из неупорядоченности кортежей следует, во-первых, что в отношении не существует другого способа адресации кортежей, кроме адресации по ключу; во-вторых, что в отношении не существует
# таких понятий как первый кортеж, последний, предыдущий, следующий и т. п.
#
# Из неупорядоченности атрибутов следует, что единственным способом их адресации в запросах является использование наименования атрибута.
#
# <p style="color:#444444;"> <i><u>Замечание.</u></i> В отношениях, являющихся результатами запросов, SQL допускает наличие одинаковых строк. Для их устранения в запросе используется ключевое слово DISTINCT.</p>
#
# Информация в реляционных базах данных, как правило, хранится не в одной таблице-отношении, а в нескольких. Для работы со связанными данными из нескольких таблиц важным является понятие так называемых внешних ключей. Внешним ключом таблицы называется атрибут или набор атрибутов этой таблицы, каждое значение которых в текущем состоянии таблицы всегда совпадает со значением атрибутов, являющихся ключом, в другой таблице. Внешние ключи используются для связывания значений атрибутов из разных таблиц. С помощью внешних ключей обеспечивается так называемая ссылочная целостность базы данных, т. е. согласованность данных, описывающих одни и те же объекты, но хранящихся в разных таблицах.
#
# Язык SQL ориентирован на множества. Это означает, что в качестве входной информации для
# формулируемого на языке SQL запроса к базе данных используется множество кортежей-записей одной или нескольких таблиц-отношений. В результате выполнения запроса также образуется множество кортежей результирующей таблицы-отношения.
#
# ## 1.2. Интерактивный и встроенный SQL
# Существуют и используются две формы языка SQL: интерактивный SQL и встроенный SQL.  Интерактивный SQL используется для непосредственного ввода SQL-запросов пользователем и получения результата в интерактивном режиме.  Встроенный SQL состоит из команд SQL, встроенных внутрь программ, которые обычно написаны на некотором другом языке (Java, С, Python и др.)
#
# ## 1.3. Составные части SQL
# В языке SQL выделяют язык определения и язык обработки данных.
# - Язык определения данных – DDL (Data Definition Language), дает возможность создания, изменения и удаления различных объектов базы данных (таблиц, индексов, пользователей, привилегий и т. д.).
# - Язык обработки данных – DML (Data Manipulation Language), предоставляет возможность выборки информации из базы данных и ее преобразования.
#
# ## 1.4. Типы данных SQL
# В языке SQL имеются средства, позволяющие для каждого атрибута указывать тип данных, которому должны соответствовать все значения этого атрибута. Следует отметить, что определения типов данных в конкретных реализациях языка могут отличаться.
#
# ## 1.5. Используемые термины и обозначения
#
# Ключевые слова – это используемые в выражениях SQL слова, имеющие специальное назначение (например, они могут обозначать конкретные команды SQL). Ключевые слова нельзя использовать для других целей, к примеру, в качестве имен объектов базы данных. Команды, или предложения, являются инструкциями, с помощью которых SQL обращается к базе данных.
#
# ## 1.6. Учебная база данных
#
# <img src="./Img/img_02.png">
# <img src="./Img/img_03.png">
# <img src="./Img/img_04.png">
# <img src="./Img/img_05.png">
# <img src="./Img/img_06.png">
# <img src="./Img/img_07.png">

# %% [markdown]
# Ответьте на вопросы
# 1. Какие поля приведенных таблиц являются первичными ключами?
# 2. Какие данные хранятся в столбце 2 в таблице “Предмет обучения”?
# 3. Как по-другому называется строка? Столбец?
# 4. Почему мы не можем запросить для просмотра первые пять строк?

# %% [markdown]
# # 2. Выборка данных (оператор SELECT)
#
# ## 2.1. Простейшие SELECT-запросы
#
# Оператор SELECT (ВЫБРАТЬ) языка SQL является самым важным и самым часто используемым оператором.
#
# `SELECT [DISTINCT] <список атрибутов>
#     FROM <список таблиц>
#     [WHERE <условие выборки>]
#     [ORDER BY <список атрибутов>]
#     [GROUP BY <список атрибутов>]
#     [HAVING <условие>]
#     [UNION <выражение с оператором SELECT>]`
#
# Обязательным ключевым словом в предложении-запросе SELECT является слово FROM (из). За ключевым словом FROM указывается список разделенных запятыми имен таблиц.
#
# Пример:
# ```
# SELECT NAME, SURNAME
#     FROM STUDENT;
# ```
# <img src="./Img/img_08.png">
#
# Если необходимо вывести значения всех столбцов таблицы, то можно вместо перечисления их имен использовать символ “*” (звездочка)
# ```
# SELECT *
#     FROM STUDENT;
# ```
#
# Получаемые в результате SQL-запроса таблицы не в полной мере отвечают определению реляционного отношения. В частности, в них могут оказаться кортежи с одинаковыми значениями атрибутов. Например, запрос “Получить список названий городов, где проживают студенты, сведения о которых находятся в таблице STUDENT”, можно записать в следующем виде
#
# ```
# SELECT CITY FROM STUDENT;
# ```
#
# Его результатом будет таблица
#
# <img src="./Img/img_09.png">
#
# Для исключения из результата SELECT-запроса повторяющихся записей используется ключевое слово DISTINCT (отличный). Запрос “Определить список названий различных городов, где проживают студенты, сведения о которых находятся в таблице STUDENT”, можно записать в следующем виде.
#
# ```
# SELECT DISTINCT CITY
#     FROM STUDENT;
# ```
#
# Использование в операторе SELECT предложения, определяемого ключевым словом WHERE (где), позволяет задавать выражение условия (предикат), принимающее значение "Истина" или "Ложь" (а также неизвестно при использовании NULL) для значений полей строк таблиц, к которым обращается оператор SELECT. Предложение WHERE определяет, какие строки указанных таблиц должны быть выбраны. В таблицу, являющуюся результатом запроса, включаются только те строки, для которых условие принимает истинное значение.
#
# Пример.
# ```
# SELECT SURNAME,  NAME
#     FROM STUDENT
#     WHERE SURNAME = "Петров";
# ```
# <img src="./Img/img_10.png">
#
# В задаваемых в предложении WHERE условиях могут использоваться операции сравнения, определяемые следующими операторами: = (равно), > (больше), < (меньше), >= (больше или равно), <= (меньше или равно), <> (не равно), а также логические операторы AND, OR и NOT. Например, запрос для получения имен и фамилий студентов, обучающихся на третьем курсе и получающих стипендию (размер стипендии больше нуля), будет выглядеть таким образом:
# ```
# SELECT NAME, SURNAME
#     FROM STUDENT
#     WHERE (KURS = 3 AND STIPEND > 0);
# ```
# <img src=./Img/icon-4017417__340.webp style="width:190px;height:190px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос к таблице SUBJECT, выводящий для каждой ее строки идентификатор (номер) предмета обучения, его наименование, семестр, в котором он читается, и количество отводимых на него часов.
# 2. Напишите запрос, позволяющий вывести все строки таблицы EXAM_MARKS, в которых предмет обучения имеет номер (SUBJ_ID), равный 12.
# 3. Напишите запрос, выбирающий все данные из таблицы STUDENT, расположив столбцы таблицы в следующем порядке: KURS, SURNAME, NAME, STIPEND.
# 4. Напишите запрос SELECT,  который выполняет вывод наименований предметов обучения (SUBJ_NAME) и следом за ним количества часов (HOUR) для каждого предмета обучения (SUBJECT) в 4-м семестре (SEMESTER).
# 5. Напишите запрос, позволяющий получить из таблицы EXAM_MARKS значения столбца MARK (экзаменационная оценка) для всех студентов, исключив из списка повторение одинаковы строк.
# 6. Напишите запрос, который выполняет вывод списка фамилий студентов, обучающихся на третьем и более старших курсах.
# 7. Напишите  запрос, выбирающий данные о фамилии, имении, номере курса для студентов, получающих стипендию больше 200.
# 8. Напишите запрос, выполняющий выборку из таблицы SUBJECT названий всех предметов обучения, на которые отводится более 30 часов.
# 9. Напишите запрос, который выполняет вывод списка университетов, рейтинг которых превышает 300 баллов.
# 10. Напишите запрос к таблице STUDENT для вывода списка фамилий (SURNAME), имен (NAME) и номера курса (KURS) всех студентов со стипендией большей или равной 100, и живущих в Воронеже.
# 11. Какие данные будут получены в результате выполнения запроса?
# ```
# SELECT *
# FROM STUDENT
# WHERE (STIPEND < 100 OR
#     NOT (BIRTHDAY >= "1990-03-10"
#     AND STUDENT_ID > 59));
# ```
# 12. Какие данные будут получены в результате выполнения запроса?
# ```
# SELECT *
#     FROM STUDENT
#     WHERE NOT ((BIRTHDAY = "1990-03-10" OR
#         STIPEND > 100)
#         AND STUDENT_ID >= 59)
# ```
# 13. Напишите запрос для получения списка студентов старше 25 лет, обучающихся на 1-м курсе.
# 14. Напишите запрос для получения списка предметов, для которых в 1-м семестре отведено более 100 часов.
# 15. Напишите запрос для получения списка преподавателей, живущих в Воронеже.
# 16. Напишите запрос для получения списка университетов, расположенных в Москве и имеющих рейтинг меньший, чем у ВГУ.
# 17. Напишите запрос для получения списка студентов, проживающих в Воронеже и не получающих стипендию.
# 18. Напишите запрос для получения списка студентов моложе 20 лет.
# 19. Напишите запрос для получения списка студентов без определенного места жительства.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания 1-19 c помощью Python и библиотеки SQLAlchemy</p>

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 14 октября 2021 года<br>
# ФРФТ20-2; ФРФТ20-1; ОД/207 (ул. Олеко Дундича, 23)

# %% [markdown]
# ## 2.2. Операторы IN, BETWEEN, LIKE, IS NULL
#
# Операторы IN (равен любому из списка) и NOT IN (не равен ни одному из списка) используются для сравнения проверяемого значения поля с заданным списком. Этот список значений указывается в скобках справа от оператора IN.
#
# Пример.<br> Получить из таблицы EXAM_MARKS сведения о студентах, имеющих экзаменационные оценки только 4 и 5.
# ```
# SELECT *
#     FROM EXAM_MARKS
#     WHERE MARK IN (4, 5);
# ```
#
# Пример.<br> Получить сведения о студентах, не имеющих ни одной экзаменационной оценки 4 или 5.
# ```
# SELECT *
#     FROM EXAM_MARKS
#     WHERE MARK NOT IN (4, 5)
# ```
#
# Список значений не обязательно задается в явном виде, он может представлять собой результат подзапроса.
# ```
# SELECT *
#     FROM student
#     WHERE city in (select city from lecturer);
# ```
#
# Оператор BETWEEN используется для проверки условия вхождения значения поля в заданный интервал, т. е. вместо списка значений атрибута этот оператор задает границы его изменения.
#
# Пример.<br>Получить сведения о предметах обучения, для которых количество отводимых часов лежит в пределах между 34 и 40.
# ```
# SELECT *
#     FROM SUBJECT
#     WHERE HOUR BETWEEN 34 AND 40;
# ```
#
# Оператор LIKE применим только к символьным полям типа CHAR или VARCHAR. Этот оператор осуществляет просмотр строковых значений полей с целью определения, входит ли заданная в операторе LIKE подстрока (образец поиска) в символьную строку, являющуюся значением проверяемого поля.
#
# можно применять шаблон искомого образца строки, использующий следующие символы:
# - символ подчеркивания “_”, указанный в шаблоне образца, определяет возможность наличия в указанном месте одного любого символа;
# - символ “%” допускает присутствие в указанном месте проверяемой строки последовательности любых символов произвольной длины.
#
# Пример.<br>Написать запрос, выбирающий из таблицы STUDENT сведения о студентах, у которых фамилии начинаются на букву “Р”.
# ```
# SELECT *
# FROM STUDENT
# WHERE SURNAME LIKE "Р%";
# ```
#
# В операторах сравнения =, <, >, <=, >=, <> и операторах **IN**, **BETWEEN** и **LIKE** при использовании **NULL** в качестве операнда будет возвращаться также **NULL**. В связи с этим, для проверки содержимого поля на наличие (отсутствие) в нем пустого значения **NULL** следует использовать специально предназначенные для этого операторы **IS NULL** (ЯВЛЯЕТСЯ ПУСТЫМ) и **IS NOT NULL** (НЕ ЯВЛЯЕТСЯ ПУСТЫМ), а не выражения = **NULL** или <> **NULL**.
#
# <img src=./Img/icon-4017417__340.webp style="width:190px;height:190px">
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос, выполняющий вывод находящихся в таблице EXAM_MARKS номеров предметов обучения, экзамены по которым сдавались в 2000 году.
# 2. Напишите запрос, выбирающий данные обо всех предметах обучения, экзамены по которым сданы студентами с идентификаторами 12 и 32.
# 3. Напишите запрос, который выполняет вывод названий предметов обучения, начинающихся на букву ‘И’.
# 4. Напишите запрос, выбирающий сведения о студентах, у которых имена начинаются на букву ‘И’ или ‘С’.
# 5. Напишите запрос для выбора из таблицы EXAM_MARKS записей, для которых отсутствуют значения оценок (поле MARK).
# 6. Напишите запрос, выполняющий вывод из таблицы EXAM_MARKS записей, для которых в поле MARK проставлены значения оценок для экзаменов в 2019 году.
# 7. Напишите запрос для получения списка преподавателей, проживающих в городах, в названиях которых присутствует дефис.
# 8. Напишите запрос для получения списка учебных заведений, в названиях которых использованы кавычки.
# 9. Напишите запрос для получения списка предметов, названия которых оканчиваются на ‘ия’.
# 10. Напишите запрос для получения списка учебных заведений, в названиях которых содержится слово ‘университет’.
# 11. Напишите запрос для получения списка студентов, фамилии которых начинаются на ‘Ков’ или на ‘Куз’.
# 12. Напишите запрос для получения списка предметов обучения, названия которых состоят из более одного слова.
# 13. Напишите запрос для получения списка учебных заведений, названия которых состоят как минимум из трех слов.
# 14. Напишите запрос для получения списка студентов, фамилии которых состоят из трех букв.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания 1-14 c помощью Jupyter Notebook и языка програмирования Python</p>

# %%
#Ответы на задания раздела 2.2. Операторы IN, BETWEEN, LIKE, IS NULL
from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_, cast, String
from sqlalchemy.sql import func
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1 Способ 1, с помощью .between()
s=select([exam_marks.c.subj_id.distinct()])
s=s.where(exam_marks.c.exam_date.between("2000-01-01","2000-12-31"))
print(str(s)) # Если запрос сложный, то распечатываем выражение на языке SQL для самопроверки
print(s.compile().params)
result=conn.execute(s).fetchall()
print(result)
# Out:
# SELECT DISTINCT exam_marks.subj_id
# FROM exam_marks
# WHERE exam_marks.exam_date BETWEEN :exam_date_1 AND :exam_date_2
# {'exam_date_1': '2000-01-01', 'exam_date_2': '2000-12-31'}
# [(10,), (22,)]

# %%
#1 Способ 2, с помощью операторов >= , <=
s=select([exam_marks.c.subj_id.distinct()])
s=s.where(exam_marks.c.exam_date>="2000-01-01")
s=s.where(exam_marks.c.exam_date<="2000-12-31")
print(str(s)) # Если запрос сложный, то распечатываем выражение на языке SQL для самопроверки
print(s.compile().params)
result=conn.execute(s).fetchall()
print(result)
# Out:
# SELECT DISTINCT exam_marks.subj_id
# FROM exam_marks
# WHERE exam_marks.exam_date >= :exam_date_1 AND exam_marks.exam_date <= :exam_date_2
# {'exam_date_1': '2000-01-01', 'exam_date_2': '2000-12-31'}
# [(10,), (22,)]

# %%
#1 Способ 3, с помощью datetime()
from datetime import datetime
start_date = datetime(2000,1,1)
end_date = datetime(2000,12,31)
s=select([exam_marks.c.subj_id.distinct()])
s=s.where(and_(exam_marks.c.exam_date>=start_date, exam_marks.c.exam_date<=end_date))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10,), (22,)]

# %%
#2
s=select([exam_marks.c.subj_id])
s=s.where(exam_marks.c.student_id.in_([12,32]))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10,), (10,), (10,)]

# %%
#3
s=select([subject.c.subj_name])
s=s.where(subject.c.subj_name.startswith("И"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Информатика',), ('История',)]

# %%
#4
s=select([student.c.name, student.c.surname])
s=s.where(or_(student.c.name.startswith("И"),student.c.name.startswith("С")))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Иван', 'Иванов'), ('Софья', 'Дементьева'), ('Ия', 'Соколова'), ('Ирина', 'Пак'), ('Синицин', 'Кондрат'), ('Светлана', 'Мишина'), ('Ирина', 'Сорокина'), ('Ирина', 'Жданова'), ('Ираида', 'Блохина'), ('Светлана', 'Мельникова'), ('Самуил', 'Никитин'), ('Икром', 'Назаров'), ('Софон', 'Захаров'), ('Иннокентий', 'Колобов'), ('Савва', 'Юдин'), ('Ипат', 'Комаров'), ('Семен', 'Симонов')]

# %%
#5 С помощью is_(None)
s=select([exam_marks])
s=s.where(exam_marks.c.mark.is_(None))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(639, 55, 10, None, datetime.datetime(2019, 5, 29, 0, 0))]

# %%
#6 С помощью isnot(None)
s=select([exam_marks])
s=s.where(exam_marks.c.exam_date.between("2019-01-01","2019-12-31"))
s=s.where(exam_marks.c.mark.isnot(None))
result=conn.execute(s).fetchall()
print(result, len(result))
# Out:
# [(10, 110, 22, 1, datetime.datetime(2019, 12, 25, 0, 0)), (12, 88, 56, 5, datetime.datetime(2019, 9, 2, 0, 0)), (14, 85, 13, 1, datetime.datetime(2019, 5, 29, 0, 0)), (16, 92, 10, 5, datetime.datetime(2019, 5, 29, 0, 0)), (18, 101, 94, 2, datetime.datetime(2019, 5, 26, 0, 0)), (23, 90, 22, 4, datetime.datetime(2019, 5, 29, 0, 0)), (25, 77, 12, 1, datetime.datetime(2019, 5, 29, 0, 0)), (28, 10, 12, 5, datetime.datetime(2019, 5, 29, 0, 0)), (30, 82, 56, 5, datetime.datetime(2019, 5, 29, 0, 0)), (31, 73, 11, 1, datetime.datetime(2019, 5, 29, 0, 0)), (95, 149, 13, 2, datetime.datetime(2019, 5, 29, 0, 0))] 11

# %%
#7
s=select([lecturer])
s=s.where(lecturer.c.city.like("%-%"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(15, 'Прокофий', 'Дорофеев', 'Санкт-Петербург', 32)]

# %%
#8
s=select([university])
s=s.where(university.c.univ_name.contains("\""))
print(s, s.compile().params)
result=conn.execute(s).fetchall()
print(result)
# Out:
# SELECT university.univ_id, university.univ_name, university.rating, university.city
# FROM university
# WHERE (university.univ_name LIKE '%' || :univ_name_1 || '%') {'univ_name_1': '"'}
# []

# %%
#9
s=select(subject.c.subj_name)
s=s.where(subject.c.subj_name.endswith("ия"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('История',)]

# %%
#10
s=select([university])
s=s.where(university.c.univ_name.contains("У"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 'ВГУ', 296, 'Воронеж'), (11, 'НГУ', 345, 'Новосибирск'), (14, 'БГУ', 326, 'Белгород'), (15, 'ТГУ', 368, 'Томск'), (22, 'МГУ', 606, 'Москва'), (32, 'РГУ', 416, 'Ростов'), (44, 'ФинУ', 330, 'Москва'), (45, 'МГТУ', 372, 'Москва'), (47, 'КФУ', 330, 'Казань'), (48, 'УЛГУ', 231, 'Ульяновск')]

# %%
#11
s=select(student)
s=s.where(or_(student.c.surname.startswith("Ков"),student.c.surname.startswith("Куз")))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 'Кузнецов', 'Борис', 0, 2, 'Брянск', datetime.datetime(2001, 12, 8, 0, 0), 10), (131, 'Ковалев', 'Ефим', 200, 2, 'Волгоград', datetime.datetime(1995, 11, 28, 0, 0), 47)]

# %%
#12
s=select(subject)
s=s.where(or_(subject.c.subj_name.contains(" "),subject.c.subj_name.contains("-")))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(11, 'Программирование на языках Python и SQL', 34, 2), (12, 'Анализ данных', 42, 1), (14, 'Обработка данных и моделирование в Excel', 36, 3), (23, 'Теория вероятностей и математическая статистика', 72, 4), (94, 'Английский язык', 56, 3)]

# %%
#13
s=select(university)
s=s.where(university.c.univ_name.like("% % %"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# []

# %%
#14
s=select(student.c.name,student.c.surname)
s=s.where(student.c.surname.like("___"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Елизавета', 'Дуб'), ('Ирина', 'Пак'), ('Оксана', 'Жук')]

# %% [markdown]
# ## 2.3. Преобразование вывода и встроенные функции
#
# В SQL реализованы операторы преобразования данных и встроенные функции, предназначенные для работы со значениями столбцов
# и/или константами в выражениях. Использование этих операторов допустимо в запросах везде, где можно использовать выражения.
#
# ### Числовые, символьные и строковые константы
#
# Если в запросе вместо спецификации столбца SQL обнаруживает число, то оно интерпретируется как *числовая константа*. Символьные константы должны указываться в одинарных кавычках. Если одинарная кавычка должна выводиться как часть строковой константы, то ее нужно предварить другой одинарной кавычкой.
# ```
# SELECT 'Фамилия', SURNAME, 'Имя', NAME, 100
# 	FROM STUDENT;
# ```
# ### Арифметические операции для преобразования числовых данных
#
# - Унарный (одиночный) оператор − (знак минус) изменяет знак числового значения, перед которым он стоит, на противоположный.
# - Бинарные операторы +, −, * и / предоставляют возможность выполнения арифметических операций сложения, вычитания, умножения и деления.
# ```
# SELECT SURNAME, NAME, STIPEND, KURS, -(STIPEND*KURS)/2
# 	FROM STUDENT
# 	WHERE KURS = 4 AND STIPEND > 0;
# ```
#
# ### Символьная операция конкатенации строк
#
# Операция конкатенации, обозначаемая символом “||”, позволяет соединять (“склеивать”) значения двух или более столбцов символьного типа или символьных констант в одну строку.
# ```
# SELECT surname || '_' || name, stipend
# 	FROM student
# 	WHERE kurs = 4 AND stipend > 200;
# ```
#
# ### Символьные строковые функции
#
# **LTRIM** — удаление левых граничных символов.
# ```
# LTRIM(<строка>[, <подстрока>])
# ```
# - из <строки> удаляются слева символы, указанные в <подстроке>;
# - если <подстрока> не указана, то по умолчанию удаляются пробелы;
# - в <строку> справа добавляется столько пробелов, сколько символов слева было удалено, т. е. длина <строки> остается неизменной.
#
# **RTRIM** — удаление правых граничных символов
# ```
# RTRIM(<строка>[, <подстрока>]
# ```
# Пример.
# ```
# SELECT RTRIM(univ_name, "УГ") FROM university;
# ```
#
# **SUBSTR** — выделение подстроки
#
# ```
# SUBSTR(<строка>, <начало>[, <количество>]
# ```
# - из <строки> выбирается заданное <количество> символов, начиная с указанной позиции в строке <начало>;
# - если <количество> не задано, символы выбирают с <начала> и до конца <строки>.
#
# Пример.
# ```
# SELECT substr(subj_name,1,6) FROM subject;
# ```
#
# **INSTR** — поиск подстроки
# ```
# INSTR(<строка>, <подстрока>)
# ```
# - тип возвращаемого значения — INT;
# - функция возвращает позицию найденной подстроки.
#
# **LENGTH** — определение длины строки
# - длина <строки>, тип возвращаемого значения — INT;
# - функция возвращает NULL, если <строка> имеет NULL-значение.
#
# Пример.
# ```
# SELECT subj_name, length(subj_name)
# 	FROM subject;
# ```
# <img src=./Img/icon-4017417__340.webp style="width:190px;height:190px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Составьте запрос для таблицы STUDENT таким образом, чтобы в результат содержал только студентов, чья фамилия заканчивается на "ова" и чтобы выходная таблица содержала всего один столбец в следующем виде: В. Кудряшова; место жительства - Нижневартовск; день рождения 2002-02-18.
# 2. Составьте запрос, выводящий фамилии, имена студентов и величину получаемых ими стипендий, при этом значения стипендий должны быть увеличены в 100 раз.
# 3. Составьте запрос для таблицы UNIVERSITY таким образом, чтобы выходная таблица содержала всего один столбец в следующем виде: Код-10; ВГУ-г.ВОРОНЕЖ; Рейтинг=296.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# Выполните задания 1-3 c помощью Jupyter Notebook и языка програмирования Python

# %%
#Ответы на задания раздела 2.3 Преобразование вывода и встроенные функции
from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_, cast, String
from sqlalchemy.sql import func
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1
s=select(func.substr(student.c.name,0,2)+"."+student.c.surname+"; "+
         "место жительства-"+student.c.city+"; "+"день рождения "+
         func.substr(cast(student.c.birthday,String()),0,11))
s=s.where(student.c.surname.like("%ова"))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('В.Кудряшова; место жительства-Нижневартовск; день рождения 2002-02-18',), ('П.Рожкова; место жительства-Рубцовск; день рождения 2001-09-15',), ('И.Соколова; место жительства-Колпашево; день рождения 2002-06-25',), ('В.Семенова; место жительства-Вологда; день рождения 2003-10-04',), ('В.Некрасова; место жительства-Иркутск; день рождения 2004-08-23',), ('О.Казакова; место жительства-Кемерово; день рождения 2000-03-29',), ('А.Миронова; место жительства-Владикавказ; день рождения 2000-10-08',), ('Л.Одинцова; место жительства-Верхний Баскунчак; день рождения 2002-03-07',), ('З.Игнатова; место жительства-Ростов; день рождения 2000-09-26',), ('Д.Мельникова; место жительства-Архангельск; день рождения 2002-08-01',), ('В.Фролова; место жительства-Кисловодск; день рождения 1999-06-02',), ('Г.Шашкова; место жительства-Кущевская; день рождения 2001-08-15',), ('М.Казакова; место жительства-Нальчик; день рождения 1994-02-18',), ('Ф.Жукова; место жительства-Магадан; день рождения 1998-10-06',), 
# ...

# %%
#2
s=select([student.c.surname, student.c.name,student.c.stipend*100])
result=conn.execute(s).fetchone()
print(result)
# Out:
# ('Иванов', 'Иван', 15000)

# %%
#3
s=select("Код-"+university.c.univ_id+"; "+university.c.univ_name+"; "+"рейтинг="+university.c.rating)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(306,), (356,), (340,), (383,), (345,), (628,), (448,), (374,), (417,), (346,), (377,), (279,)]

# %%
s=select("Код-"+cast(university.c.univ_id,String())+"; "+
         university.c.univ_name+"; "+"рейтинг="+cast(university.c.rating,String()))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Код-10; ВГУ; рейтинг=296',), ('Код-11; НГУ; рейтинг=345',), ('Код-14; БГУ; рейтинг=326',), ('Код-15; ТГУ; рейтинг=368',), ('Код-18; ВГМА; рейтинг=327',), ('Код-22; МГУ; рейтинг=606',), ('Код-32; РГУ; рейтинг=416',), ('Код-44; ФинУ; рейтинг=330',), ('Код-45; МГТУ; рейтинг=372',), ('Код-46; Политех; рейтинг=300',), ('Код-47; КФУ; рейтинг=330',), ('Код-48; УЛГУ; рейтинг=231',)]

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 18 октября 2021 года<br>
# ФРФТ20-2; ФРФТ20-1; ОД/207 (ул. Олеко Дундича, 23)

# %% [markdown]
# ## 2.4. Агрегирование и групповые функции
#
# Агрегирующие функции позволяют получать из таблицы сводную (агрегированную) информацию, выполняя операции над группой строк
# таблицы. Для задания в SELECT-запросе агрегирующих операций используются следующие ключевые слова:
# - COUNT определяет количество строк или значений поля, выбранных посредством запроса и не являющихся NULL-значениями;
# - SUM вычисляет арифметическую сумму всех выбранных значений данного поля;
# - AVG вычисляет среднее значение для всех выбранных значений данного поля;
# - MAX вычисляет наибольшее из всех выбранных значений данного поля;
# - MIN вычисляет наименьшее из всех выбранных значений данного поля.
#
# ```
# SELECT min(rating), max(rating), round(avg(rating),2), count(univ_id)
# 	FROM university;
#
# SELECT count(DISTINCT subj_id)
#     FROM subject;
# ```
#
# Предложение GROUP BY позволяет применять агрегирующие функции к каждой группе, определяемой общим значением поля или полей, указанных в этом предложении.
# ```
# SELECT exam_marks.student_id, max(exam_marks.mark)
# 	FROM exam_marks
# 	GROUP by exam_marks.student_id;
# ```
#
# В конструкции GROUP BY для группирования может быть использовано более одного столбца.
# ```
# SELECT student_id, subj_id, max(mark)
#     FROM exam_marks
#     GROUP BY student_id, subj_id
# ```
# Следует иметь в виду, что после ключевого слова SELECT должны быть использованы только те имена столбцов, которые указаны в
# предложении GROUP BY.
#
# Предложение HAVING определяет критерий, по которому группы следует включать в выходные данные (по аналогии с предложением
# WHERE, которое осуществляет это для отдельных строк):
#
# ```
# SELECT subj_name, max(HOUR)
# 	FROM subject
# 	GROUP BY subj_name
# 	HAVING max(hour) >= 50 AND max(hour)<70
# ```
# <img src=./Img/icon-4017417__340.webp style="width:190px;height:190px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос для подсчета количества студентов, сдававших экзамен по предмету обучения с идентификатором 73.
# 2. Напишите запрос, который позволяет подсчитать в таблице EXAM_MARKS количество различных предметов обучения.
# 3. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и минимальной из полученных им оценок.
# 4. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и максимальной из полученных им оценок.
# 5. Напишите запрос, выполняющий вывод первой по алфавиту фамилии студента, начинающейся на букву "И".
# 6. Напишите запрос, который для каждого предмета обучения выводит наименование предмета и максимальное значение номера семестра, в котором этот предмет преподается.
# 7. Напишите запрос, который для каждого конкретного дня сдачи экзамена выводит данные о количестве студентов, сдававших экзамен в этот день.
# 8. Напишите запрос, выдающий средний балл для каждого студента.
# 9. Напишите запрос, выдающий средний балл для экзамена по каждому предмету.
# 10. Напишите запрос, определяющий количество сдававших студентов для каждого предмета (оценка больше двух).
# 11. Напишите запрос для определения количества предметов, изучаемых на каждом курсе.
# 12. Для каждого университета напишите запрос, выводящий суммарную стипендию обучающихся в нем студентов, с последующей сортировкой списка по этому значению.
# 13. Для каждого семестра напишите запрос, выводящий общее количество часов, отводимое на изучение соответствующих предметов.
# 14. Для каждого студента напишите запрос, выводящий среднее значение оценок, полученных им на всех экзаменах.
# 15. Для каждого студента напишите запрос, выводящий среднее значение оценок, полученных им по каждому предмету.
# 16. Напишите запрос, выводящий количество студентов, проживающих в каждом городе. Список отсортировать в порядке убывания количества студентов.
# 17. Для каждого университета напишите запрос, выводящий количество обучающихся в нем студентов, с последующей сортировкой списка по этому количеству.
# 18. Для каждого университета напишите запрос, выводящий количество работающих в нем преподавателей, с последующей сортировкой списка по этому количеству.
# 19. Для каждого университета напишите запрос, выводящий сумму стипендии, выплачиваемой студентам каждого курса.
# 20. Для каждого города напишите запрос, выводящий максимальный рейтинг университетов, в нем расположенных, с последующей сортировкой списка по значениям рейтингов.
# 21. Для каждого дня сдачи экзаменов напишите запрос, выводящий среднее значение всех экзаменационных оценок.
# 22. Для каждого дня сдачи экзаменов напишите запрос, выводящий максимальные оценки, полученные по каждому предмету.
# 23. Для каждого дня сдачи экзаменов напишите запрос, выводящий общее количество студентов, сдававших экзамены.
# 24. Для каждого дня сдачи экзаменов напишите запрос, выводящий общее количество экзаменов, сдававшихся каждым студентом.
# 25. Для каждого преподавателя напишите запрос, выводящий количество преподаваемых им предметов.
# 26. Для каждого предмета напишите запрос, выводящий количество преподавателей, ведущих по нему занятия.
# 27. Напишите запрос, выполняющий вывод списка студентов, имеющих только отличные оценки. Результат отстортируйте по идентификатору студента.
# 28. Напишите запрос, выполняющий вывод количества экзаменов, сданных (с положительной оценкой) студентами с идентификаторами 12, 32, 38.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Ответы на задания раздела 2.4. Агрегирование и групповые функции

from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1
s=select([func.count(exam_marks.c.student_id)]).where(exam_marks.c.subj_id==73)
result=conn.execute(s)
result.scalar()
# Out:
# 4

# %%
#2
result=conn.execute(select([exam_marks.c.subj_id.distinct()])).fetchall()
print(len(result))
# Out:
# 9

# %%
#3
s=select([exam_marks.c.student_id,func.min(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.student_id)
result=conn.execute(s).fetchone() # Выводится одна запись для проверки, правильно fetchall()
print(result)
# Out:
# (1, 1)

# %%
#4
s=select([exam_marks.c.student_id,func.max(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.student_id)
result=conn.execute(s).fetchone() # Выводится одна запись для проверки, правильно fetchall()
print(result)
# Out:
# (1, 1)

# %%
#5
s=select([func.min(student.c.surname)]).where(student.c.surname.startswith("И"))
result=conn.execute(s).fetchone()
print(result)
# Out:
# ('Иванов',)

# %%
#6
s=select([subject.c.subj_name,func.max(subject.c.semester)])
s=s.group_by(subject.c.subj_name)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Анализ данных', 1), ('Английский язык', 3), ('Информатика', 1), ('История', 4), ('Математика', 2), ('ОБЖ', 2), ('Обработка данных и моделирование в Excel', 3), ('Программирование на языках Python и SQL', 2), ('Теория вероятностей и математическая статистика', 4), ('Физика', 1), ('Физкультура', 5)]

# %%
#7
s=select([exam_marks.c.exam_date, func.count(exam_marks.c.student_id)])
s=s.group_by(exam_marks.c.exam_date)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(datetime.datetime(2000, 1, 18, 0, 0), 1), (datetime.datetime(2000, 1, 23, 0, 0), 2), (datetime.datetime(2006, 5, 12, 0, 0), 1), (datetime.datetime(2006, 6, 17, 0, 0), 1), (datetime.datetime(2019, 5, 26, 0, 0), 1), (datetime.datetime(2019, 5, 29, 0, 0), 9), (datetime.datetime(2019, 9, 2, 0, 0), 1), (datetime.datetime(2019, 12, 25, 0, 0), 1), (datetime.datetime(2019, 12, 31, 0, 0), 1), (datetime.datetime(2020, 2, 10, 0, 0), 1), (datetime.datetime(2020, 2, 21, 0, 0), 3), (datetime.datetime(2020, 2, 22, 0, 0), 1), (datetime.datetime(2020, 5, 26, 0, 0), 7), (datetime.datetime(2020, 5, 27, 0, 0), 2), (datetime.datetime(2020, 8, 18, 0, 0), 1), (datetime.datetime(2020, 9, 21, 0, 0), 1), (datetime.datetime(2020, 10, 24, 0, 0), 1), (datetime.datetime(2020, 12, 3, 0, 0), 1), (datetime.datetime(2021, 6, 2, 0, 0), 5)]

# %%
#8
s=select([exam_marks.c.student_id,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.student_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 1.0), (6, 4.0), (10, 5.0), (12, 3.5), (15, 5.0), (32, 4.0), (55, 5.0), (62, 4.0), (64, 4.0), (65, 1.0), (71, 3.0), (73, 1.0), (76, 2.0), (77, 1.0), (79, 1.0), (82, 5.0), (83, 1.0), (85, 2.5), (88, 5.0), (90, 4.0), (91, 5.0), (92, 5.0), (97, 1.0), (99, 5.0), (101, 2.0), (103, 2.0), (105, 3.0), (110, 1.0), (116, 1.0), (117, 4.0), (123, 2.0), (126, 1.0), (128, 4.0), (149, 2.0), (203, 3.0)]

# %%
#9
s=select([exam_marks.c.subj_id,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.subj_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 3.6666666666666665), (11, 1.0), (12, 2.0), (13, 2.5), (22, 2.8333333333333335), (43, 2.0), (56, 3.1666666666666665), (73, 3.0), (94, 3.6666666666666665)]

# %%
#10
s=select([exam_marks.c.subj_id,func.count(exam_marks.c.student_id)])
s=s.where(exam_marks.c.mark>2)
s=s.group_by(exam_marks.c.subj_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 7), (12, 1), (13, 1), (22, 3), (43, 1), (56, 3), (73, 3), (94, 2)]

# %%
#11
s=select([(subject.c.semester+1)/2,func.count(subject.c.subj_name)])
s=s.group_by((subject.c.semester+1)/2)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 6), (2, 4), (3, 1)]

# %%
#12
s=select([student.c.univ_id,func.sum(student.c.stipend)])
s=s.group_by(student.c.univ_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 3250), (11, 400), (14, 1700), (15, 650), (18, 1000), (22, 2180), (32, 1050), (44, 1980), (45, 650), (46, 1250), (47, 1450), (48, 1200)]

# %%
#13
s=select([subject.c.semester,func.sum(subject.c.hour)]).group_by(subject.c.semester)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 132), (2, 124), (3, 92), (4, 106), (5, 34)]

# %%
#14
s=select([exam_marks.c.student_id,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.student_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 1.0), (6, 4.0), (10, 5.0), (12, 3.5), (15, 5.0), (32, 4.0), (55, 5.0), (62, 4.0), (64, 4.0), (65, 1.0), (71, 3.0), (73, 1.0), (76, 2.0), (77, 1.0), (79, 1.0), (82, 5.0), (83, 1.0), (85, 2.5), (88, 5.0), (90, 4.0), (91, 5.0), (92, 5.0), (97, 1.0), (99, 5.0), (101, 2.0), (103, 2.0), (105, 3.0), (110, 1.0), (116, 1.0), (117, 4.0), (123, 2.0), (126, 1.0), (128, 4.0), (149, 2.0), (203, 3.0)]

# %%
#15
s=select([exam_marks.c.student_id,exam_marks.c.subj_id,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.student_id,exam_marks.c.subj_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 43, 1.0), (6, 22, 4.0), (10, 12, 5.0), (12, 10, 3.5), (15, 10, 5.0), (32, 10, 4.0), (55, 10, 5.0), (62, 94, 4.0), (64, 73, 4.0), (65, 73, 1.0), (71, 10, 3.0), (73, 11, 1.0), (76, 12, 2.0), (76, 56, 2.0), (77, 12, 1.0), (79, 12, 1.0), (82, 56, 5.0), (83, 22, 1.0), (85, 13, 1.0), (85, 73, 4.0), (88, 56, 5.0), (90, 22, 4.0), (91, 22, 5.0), (92, 10, 5.0), (97, 10, 1.0), (99, 94, 5.0), (101, 13, 2.0), (101, 94, 2.0), (103, 22, 2.0), (105, 10, 3.0), (110, 22, 1.0), (116, 12, 1.0), (117, 56, 4.0), (123, 56, 2.0), (126, 56, 1.0), (128, 13, 5.0), (128, 73, 3.0), (149, 13, 2.0), (203, 43, 3.0)]

# %%
#16
s=select([student.c.city,func.count(student.c.student_id)]).group_by(student.c.city)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(None, 2), ('Ангарск', 1), ('Архангельск', 1), ('Байкальск', 1), ('Белгород', 2), ('Беломорск', 1), ('Благовещенск (Амур.)', 1), ('Брянск', 2), ('Валдай', 1), ('Верхний Баскунчак', 1), ('Верхоянск', 1), ('Владикавказ', 1), ('Волгоград', 1), ('Вологда', 1), ('Волоколамск', 1), ('Воркута', 1), ('Воронеж', 3), ('Геленджик', 1), ('Грозный', 2), ('Дербент', 1), ('Джубга', 2), ('Екатеринбург', 1), ('Енисейск', 1), ('Жуковский', 1), ('Забайкальск', 1), ('Златоуст', 1), ('Иваново', 1), ('Игарка', 1), ('Иркутск', 2), ('Ишим', 1), ('Калининград', 1), ('Каменск-Уральский', 1), ('Камень-на-Оби', 1), ('Канск', 1), ('Кемерово', 1), ('Кизилюрт', 1), ('Кисловодск', 1), ('Колпашево', 1), ('Корсаков', 2), ('Кропоткин (Краснод.)', 2), ('Курганинск', 1), ('Курск', 3), ('Кущевская', 1), ('Кыштым', 1), ('Липецк', 2), ('Магадан', 2), ('Малая Вишера', 1), ('Москва', 3), ('Мурманск', 2), ('Нальчик', 1), ('Невельск (Сахалин)', 1), ('Невинномысск', 1), ('Нерчинск', 2), ('Нефтеюганск', 1), ('Нижневартовск', 1)
# ...

# %%
#17
s=select([student.c.univ_id,func.count(student.c.univ_id)])
s=s.group_by(student.c.univ_id)
s=s.order_by(func.count(student.c.univ_id))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(11, 4), (15, 4), (45, 5), (32, 7), (48, 7), (18, 8), (47, 9), (46, 10), (44, 11), (14, 12), (22, 14), (10, 21)]

# %%
#18
s=select([lecturer.c.univ_id, func.count(lecturer.c.lecturer_id)]).group_by(lecturer.c.univ_id)
s=s.order_by(func.count(lecturer.c.lecturer_id))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(11, 1), (45, 1), (15, 2), (22, 2), (32, 2), (47, 2), (46, 3), (48, 3), (18, 5), (10, 8)]

# %%
#19
s=select([student.c.univ_id,student.c.kurs,func.sum(student.c.stipend)]).group_by(student.c.univ_id,student.c.kurs)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 1, 850), (10, 2, 650), (10, 3, 800), (10, 4, 500), (10, 5, 450), (11, 1, 150), (11, 3, 0), (11, 4, 0), (11, 5, 250), (14, 1, 100), (14, 2, 200), (14, 3, 800), (14, 4, 250), (14, 5, 350), (15, 1, 250), (15, 2, 150), (15, 4, 250), (18, 1, 100), (18, 2, 350), (18, 4, 200), (18, 5, 350), (22, 1, 280), (22, 3, 650), (22, 4, 700), (22, 5, 550), (32, 1, 650), (32, 2, 0), (32, 4, 400), (44, 2, 930), (44, 3, 100), (44, 4, 450), (44, 5, 500), (45, 1, 150), (45, 2, 0), (45, 3, 500), (46, 1, 100), (46, 2, 550), (46, 3, 450), (46, 4, 0), (46, 5, 150), (47, 1, 400), (47, 2, 550), (47, 4, 500), (48, 2, 800), (48, 3, 200), (48, 5, 200)]

# %%
#20
s=select([university.c.city,func.max(university.c.rating)])
s=s.group_by(university.c.city)
s=s.order_by(func.max(university.c.rating))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Ульяновск', 231), ('Санкт-Петербург', 300), ('Белгород', 326), ('Воронеж', 327), ('Казань', 330), ('Новосибирск', 345), ('Томск', 368), ('Ростов', 416), ('Москва', 606)]

# %%
#21
s=select([exam_marks.c.exam_date,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.exam_date)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(datetime.datetime(2000, 1, 18, 0, 0), 4.0), (datetime.datetime(2000, 1, 23, 0, 0), 4.5), (datetime.datetime(2006, 5, 12, 0, 0), 2.0), (datetime.datetime(2006, 6, 17, 0, 0), 5.0), (datetime.datetime(2019, 5, 26, 0, 0), 2.0), (datetime.datetime(2019, 5, 29, 0, 0), 3.0), (datetime.datetime(2019, 9, 2, 0, 0), 5.0), (datetime.datetime(2019, 12, 25, 0, 0), 1.0), (datetime.datetime(2019, 12, 31, 0, 0), 3.0), (datetime.datetime(2020, 2, 10, 0, 0), 2.0), (datetime.datetime(2020, 2, 21, 0, 0), 3.0), (datetime.datetime(2020, 2, 22, 0, 0), 5.0), (datetime.datetime(2020, 5, 26, 0, 0), 2.5714285714285716), (datetime.datetime(2020, 5, 27, 0, 0), 2.0), (datetime.datetime(2020, 8, 18, 0, 0), 1.0), (datetime.datetime(2020, 9, 21, 0, 0), 5.0), (datetime.datetime(2020, 10, 24, 0, 0), 1.0), (datetime.datetime(2020, 12, 3, 0, 0), 5.0), (datetime.datetime(2021, 6, 2, 0, 0), 2.4)]

# %%
#22
s=select([exam_marks.c.exam_date,exam_marks.c.subj_id,func.avg(exam_marks.c.mark)])
s=s.group_by(exam_marks.c.exam_date,exam_marks.c.subj_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(datetime.datetime(2000, 1, 18, 0, 0), 22, 4.0), (datetime.datetime(2000, 1, 23, 0, 0), 10, 4.5), (datetime.datetime(2006, 5, 12, 0, 0), 10, 2.0), (datetime.datetime(2006, 6, 17, 0, 0), 10, 5.0), (datetime.datetime(2019, 5, 26, 0, 0), 94, 2.0), (datetime.datetime(2019, 5, 29, 0, 0), 10, 5.0), (datetime.datetime(2019, 5, 29, 0, 0), 11, 1.0), (datetime.datetime(2019, 5, 29, 0, 0), 12, 3.0), (datetime.datetime(2019, 5, 29, 0, 0), 13, 1.5), (datetime.datetime(2019, 5, 29, 0, 0), 22, 4.0), (datetime.datetime(2019, 5, 29, 0, 0), 56, 5.0), (datetime.datetime(2019, 9, 2, 0, 0), 56, 5.0), (datetime.datetime(2019, 12, 25, 0, 0), 22, 1.0), (datetime.datetime(2019, 12, 31, 0, 0), 43, 3.0), (datetime.datetime(2020, 2, 10, 0, 0), 12, 2.0), (datetime.datetime(2020, 2, 21, 0, 0), 73, 3.0), (datetime.datetime(2020, 2, 22, 0, 0), 22, 5.0), (datetime.datetime(2020, 5, 26, 0, 0), 10, 2.3333333333333335), (datetime.datetime(2020, 5, 26, 0, 0), 12, 1.0), (datetime.datetime(2020, 5, 26, 0, 0), 56, 2.5), (
# ...

# %%
#23
s=select([exam_marks.c.exam_date,func.count(exam_marks.c.student_id.distinct())])
s=s.group_by(exam_marks.c.exam_date)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(datetime.datetime(2000, 1, 18, 0, 0), 1), (datetime.datetime(2000, 1, 23, 0, 0), 2), (datetime.datetime(2006, 5, 12, 0, 0), 1), (datetime.datetime(2006, 6, 17, 0, 0), 1), (datetime.datetime(2019, 5, 26, 0, 0), 1), (datetime.datetime(2019, 5, 29, 0, 0), 9), (datetime.datetime(2019, 9, 2, 0, 0), 1), (datetime.datetime(2019, 12, 25, 0, 0), 1), (datetime.datetime(2019, 12, 31, 0, 0), 1), (datetime.datetime(2020, 2, 10, 0, 0), 1), (datetime.datetime(2020, 2, 21, 0, 0), 3), (datetime.datetime(2020, 2, 22, 0, 0), 1), (datetime.datetime(2020, 5, 26, 0, 0), 7), (datetime.datetime(2020, 5, 27, 0, 0), 2), (datetime.datetime(2020, 8, 18, 0, 0), 1), (datetime.datetime(2020, 9, 21, 0, 0), 1), (datetime.datetime(2020, 10, 24, 0, 0), 1), (datetime.datetime(2020, 12, 3, 0, 0), 1), (datetime.datetime(2021, 6, 2, 0, 0), 5)]

# %%
#24
s=select([exam_marks.c.exam_date,exam_marks.c.student_id,func.count(exam_marks.c.exam_id)])
s=s.group_by(exam_marks.c.exam_date,exam_marks.c.student_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(datetime.datetime(2000, 1, 18, 0, 0), 6, 1), (datetime.datetime(2000, 1, 23, 0, 0), 32, 1), (datetime.datetime(2000, 1, 23, 0, 0), 55, 1), (datetime.datetime(2006, 5, 12, 0, 0), 12, 1), (datetime.datetime(2006, 6, 17, 0, 0), 12, 1), (datetime.datetime(2019, 5, 26, 0, 0), 101, 1), (datetime.datetime(2019, 5, 29, 0, 0), 10, 1), (datetime.datetime(2019, 5, 29, 0, 0), 55, 1), (datetime.datetime(2019, 5, 29, 0, 0), 73, 1), (datetime.datetime(2019, 5, 29, 0, 0), 77, 1), (datetime.datetime(2019, 5, 29, 0, 0), 82, 1), (datetime.datetime(2019, 5, 29, 0, 0), 85, 1), (datetime.datetime(2019, 5, 29, 0, 0), 90, 1), (datetime.datetime(2019, 5, 29, 0, 0), 92, 1), (datetime.datetime(2019, 5, 29, 0, 0), 149, 1), (datetime.datetime(2019, 9, 2, 0, 0), 88, 1), (datetime.datetime(2019, 12, 25, 0, 0), 110, 1), (datetime.datetime(2019, 12, 31, 0, 0), 203, 1), (datetime.datetime(2020, 2, 10, 0, 0), 76, 1), (datetime.datetime(2020, 2, 21, 0, 0), 64, 1), (datetime.datetime(2020, 2, 21, 0, 0), 65, 1), (datet
# ...

# %%
#25
s=select([subj_lect.c.lecturer_id,func.count(subj_lect.c.subj_id)])
s=s.group_by(subj_lect.c.lecturer_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 1), (2, 2), (3, 1), (5, 1), (6, 2), (11, 2), (12, 1), (15, 1), (16, 2), (18, 1), (19, 1), (20, 1), (22, 2), (23, 1), (24, 1), (46, 1), (74, 1), (108, 2)]

# %%
#26
s=select([subj_lect.c.subj_id,subj_lect.c.lecturer_id])
s=s.group_by(subj_lect.c.subj_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10, 22), (11, 18), (12, 6), (13, 19), (22, 24), (23, 2), (43, 11), (56, 46), (73, 22), (94, 74)]

# %%
#27
s=select([exam_marks.c.student_id.distinct()])
s=s.where(exam_marks.c.mark==5)
s=s.order_by(exam_marks.c.student_id)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(10,), (12,), (15,), (55,), (82,), (88,), (91,), (92,), (99,), (128,)]

# %%
#28 Способ 1: с использованием and_() и or_()
s=select([func.count(exam_marks.c.exam_id)])
s=s.where(and_(exam_marks.c.mark>2,or_(
    exam_marks.c.student_id==12,exam_marks.c.student_id==32,exam_marks.c.student_id==128
)))
result=conn.execute(s).fetchall()
print(result)

#28 Способ 2: с использованием and_() и in_()
s=select([func.count(exam_marks.c.exam_id)])
s=s.where(and_(exam_marks.c.mark>2,exam_marks.c.student_id.in_([12,32,128])))
result=conn.execute(s).fetchone()
print(result)

#28 Способ 3: с использованием in_()
s=select([func.count(exam_marks.c.exam_id)])
s=s.where(exam_marks.c.mark>2)
s=s.where(exam_marks.c.student_id.in_([12,32,128]))
result=conn.execute(s).scalar()
print(result)
# Out:
# [(4,)]
# (4,)
# 4

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 25 октября 2021 года<br>
# ФРФТ20-2; ФРФТ20-1; ОД/207 (ул. Олеко Дундича, 23)

# %% [markdown]
# ## 2.5. Неопределенные значения (NULL) в агрегирующих функциях
#
# Отсутствие значений в полях таблицы, обозначенное ключевым
# словом NULL, приводит к особенностям при выполнении агрегирующих
# операций над данными, которые следует учитывать при их использо-
# вании в SQL-запросах.
#
# **Влияние NULL-значений в функции COUNT.** Если аргумент функции COUNT является константой или столбцом без пустых значений, то функция возвращает количество строк, к которым применимо определенное условие или группирование.
#
# Если аргументом функции является столбец, содержащий пустое значение, то COUNT вернет число строк, которые не содержат пустые значения и к которым применимо определенное условие или группирование.
#
# Поведение функции `COUNT(*)` не зависит от пустых значений. Она
# возвратит общее количество строк в таблице.
#
# **Влияние NULL-значений в функции AVG.** Среднее значение множества чисел равно сумме чисел, деленной на число элементов множества. Однако если некоторые элементы пусты, т. е. их значения неизвестны или не существуют, то деление на количество всех элементов множества приведет к неправильному результату.
#
# Функция AVG вычисляет среднее значение всех известных значений множества элементов, т. е. эта функция подсчитывает сумму известных значений и делит ее на количество этих значений, а не на общее количество значений, среди которых могут быть NULL-значения. Если столбец состоит только из пустых значений, то функция AVG также возвратит NULL.
#
#
# ## 2.6. Результат действия трехзначных операторов
#
# Условные операторы при отсутствии пустых значений возвращают либо TRUE (ИСТИНА), либо FALSE (ЛОЖЬ). Если же в столбце присутствуют пустые значения, то может быть возвращено и третье значение: UNKNOWN (НЕИЗВЕСТНО).
#
# В этой схеме, например, условию `WHERE A=2`, где А — имя столбца, значения которого могут быть
# неизвестны, при A=2 будет соответствовать TRUE, при A=4 в результате будет получено значение FALSE, а при отсутствующем значении A (NULL-значение) результат будет UNKNOWN. Пустые значения могут оказывать влияние на использование логических операторов NOT, AND и OR.
#
# В следующей таблице показаны результаты применения оператора AND к двум логическим выражениям, когда одно выражение возвращает UNKNOWN.
# <Table>
#     <tr><th>Выражение 1</th><th>Выражение 2</th><th>Результат</th>
#     <tr><td>TRUE</td><td>UNKNOWN</td><td>UNKNOWN</td>
#     <tr><td>UNKNOWN</td><td>UNKNOWN</td><td>UNKNOWN</td>
#     <tr><td>FALSE</td><td>UNKNOWN</td><td>FALSE</td>
# </Table>
#
# В следующей таблице показаны результаты применения оператора OR к двум логическим выражениям, когда одно выражение возвращает UNKNOWN.
# <Table>
#     <tr><th>Выражение 1</th><th>Выражение 2</th><th>Результат</th>
#     <tr><td>TRUE</td><td>UNKNOWN</td><td>TRUE</td>
#     <tr><td>UNKNOWN</td><td>UNKNOWN</td><td>UNKNOWN</td>
#     <tr><td>FALSE</td><td>UNKNOWN</td><td>UNKNOWN</td>
# </Table>
#
# Для проверки наличия значения NULL в предложении WHERE запроса используются ключевые слова IS NULL или IS NOT NULL.
#
# Дополнительно прочитать о результатах действия трехзначных операторов можно здесь: https://docs.microsoft.com/ru-ru/sql/t-sql/language-elements/null-and-unknown-transact-sql?view=sql-server-ver15

# %% [markdown]
# ## 2.7. Упорядочение выходных полей (ORDER BY)
#
# Как уже отмечалось, записи в таблицах реляционной базы данных неупорядочены. Однако, данные, выводимые в результате выполнения запроса, могут быть упорядочены. Для этого в операторе SELECT используется предложение с ключевым словом ORDER BY, которое позволяет упорядочивать выводимые записи в соответствии со значениями одного или нескольких выбранных столбцов. При этом можно задать возрастающую (ASC) или убывающую (DESC) последовательность сортировки для каждого из столбцов. По умолчанию принята возрастающая последовательность сортировки. Запрос, позволяющий выбрать все данные из таблицы предметов обучения SUBJECT, с упорядочением по наименованиям предметов, выглядит следующим образом:
# ```
# SELECT *
#     FROM SUBJECT
#     ORDER BY SUBJ_NAME;
# ```
# Тот же список, но упорядоченный в обратном порядке, можно
# получить запросом:
# ```
# SELECT *
#     FROM SUBJECT
#     ORDER BY SUBJ_NAME DESC;
# ```
# Можно упорядочить выводимый список предметов обучения по значениям семестров, а внутри семестров — по наименованиям предметов:
# ```
# SELECT *
#     FROM SUBJECT
#     ORDER BY SEMESTR, SUBJ_NAME;
# ```
# Предложение ORDER BY может использоваться с GROUP BY. При этом оператор ORDER BY в запросе всегда должен быть последним:
# ```
# SELECT SUBJ_NAME, SEMESTR, MAX(HOUR)
#     FROM SUBJECT
#     GROUP BY SEMESTR, SUBJ_NAME
#     ORDER BY SEMESTR;
# ```
# При упорядочивании вместо наименований столбцов можно указывать их номера, имея, однако, в виду, что в данном случае это номера
# столбцов, указанные при определении выходных данных в запросе, а не номера столбцов в таблице. В запросе
# ```
# SELECT SUBJ_ID, SEMESTR
#     FROM SUBJECT
#     ORDER BY 2 DESC;
# ```
# выводимые записи будут упорядочены по полю SEMESTR.
#
# Если в поле, которое используется для упорядочивания, существуют NULL-значения, то все они размещаются в конце или предшествуют
# всем остальным значениям этого поля.
#
# <img src=./Img/icon-4017417__340.webp style="width:190px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Предположим, что стипендия всем студентам увеличена на 20%. Напишите запрос к таблице STUDENT, выполняющий вывод номера студента, его фамилии и величины увеличенной стипендии. Выходные данные упорядочите: а) по значению последнего столбца (величине стипендии); б) в алфавитном порядке фамилий студентов.
# 2. Напишите запрос, который по таблице EXAM_MARKS позволяет найти а) максимальные и б) минимальные оценки каждого студента и выводит их вместе с идентификатором студента.
# 3. Напишите запрос, выполняющий вывод списка предметов обучения в порядке а) убывания семестров и б) возрастания количества отводимых на предмет часов. Поле семестра в выходных данных должно быть первым, за ним должны следовать имя предмета обучения и идентификатор предмета.
# 4. Напишите запрос, который для каждой даты сдачи экзаменов выполняет вывод суммы баллов всех студентов и представляет результаты в порядке убывания этих сумм.
# 5. Напишите запрос, который для каждой даты сдачи экзаменов выполняет вывод а) среднего, б) минимального, в) максимального баллов всех студентов и представляет результаты в порядке убывания этих значений.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Ответы на задания раздела 2.7. Упорядочение выходных полей (ORDER BY).

from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1а)
S=student.alias("S")
s=select(S.c.student_id,S.c.surname,S.c.stipend*1.2)
s=s.order_by(S.c.stipend.desc())
conn.execute(s).fetchall()
# Out:
# [(12, 'Зайцева', 300.0),
#  (55, 'Белкин', 300.0),
#  (64, 'Жук', 300.0),
#  (66, 'Некрасова', 300.0),
#  (68, 'Казакова', 300.0),
#  (72, 'Пономарева', 300.0),
#  (91, 'Блохина', 300.0),
#  (92, 'Мельникова', 300.0),
#  (93, 'Щербакова', 300.0),
#  (100, 'Никитин', 300.0),
#  (103, 'Трофимов', 300.0),
#  (107, 'Морозов', 300.0),
#  (110, 'Суханов', 300.0),
#  (114, 'Панов', 300.0),
#  (130, 'Кудряшов', 300.0),
#  (141, 'Ершов', 300.0),
#  (146, 'Русаков', 300.0),
#  (149, 'Вячеслав', 300.0),
#  (203, 'Петрова', 300.0),
#  (204, 'Петров', 300.0),
#  (200, 'Баранов', 264.0),
#  (206, 'Киселев', 252.0),
#  (3, 'Петров', 240.0),
#  (67, 'Игнатьева', 240.0),
#  (70, 'Миронова', 240.0),
#  (71, 'Кондрат', 240.0),
#  (83, 'Сорокина', 240.0),
#  (88, 'Жданова', 240.0),
#  (89, 'Валерия', 240.0),
#  (97, 'Вишнякова', 240.0),
#  (101, 'Калашников', 240.0),
#  (102, 'Петров', 240.0),
#  (106, 'Медведев', 240.0),
#  (109, 'Дмитриев', 240.0),
#  (111, 'Карпов', 240.0),
# ...

# %% [markdown]
# ## 2.8. Вложенные подзапросы
# SQL позволяет использовать одни запросы внутри других запросов,
# т. е. вкладывать запросы друг в друга. Предположим, известна фами-
# лия студента (Петров), но неизвестно значение поля STUDENT_ID для
# него. Чтобы извлечь данные обо всех оценках этого студента, можно
# записать следующий запрос:
# ```
# SELECT *
# FROM EXAM_MARKS
# WHERE STUDENT_ID =
# (SELECT STUDENT_ID
# FROM STUDENT SURNAME = "Петров");
# ```
# Следует обратить внимание, что этот запрос корректен только в том случае, если в результате выполнения указанного в скобках подзапроса возвращается единственное значение. Если в результате выполнения подзапроса будет возвращено несколько значений, то при выполнении запроса будет зафиксирована ошибка. В данном примере это произойдет, если в таблице STUDENT будет несколько записей со значениями поля SURNAME = ‘Петров’.
#
# В некоторых случаях для гарантии получения единственного значения в результате выполнения подзапроса используется DISTINCT. Одним из видов функций, которые автоматически всегда выдают в результате единственное значение для любого количества строк, являются агрегирующие функции.
#
# Оператор IN также широко применяется в подзапросах. Он задает список значений, с которыми сравниваются другие значения для определения истинности задаваемого этим оператором предиката. Данные обо всех оценках (таблица EXAM_MARKS) студентов из Воронежа можно выбрать с помощью следующего запроса:
# ```
# SELECT *
#     FROM EXAM_MARKS
#     WHERE STUDENT_ID IN
#         (SELECT STUDENT_ID
#         FROM STUDENT
#         WHERE CITY = ‘Воронеж’);
# ```
# Подзапросы можно применять внутри предложения HAVING. Пусть требуется определить количество предметов обучения с оценкой, превышающей среднее значение оценки студента с идентификатором 301:
# ```
# SELECT COUNT(DISTINCT SUBJ_ID), MARK
#     FROM EXAM_MARKS
#     GROUP BY MARK
#     HAVING MARK >
#     (SELECT AVG(MARK)
#         FROM EXAM_MARKS
#         WHERE STUDENT_ID = 301);
# ```
#
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос, выводящий список студентов, получающих максимальную стипендию, отсортировав его в алфавитном порядке по фамилиям.
# 2. Напишите запрос, выводящий список студентов, получающих стипендию, превышающую среднее значение стипендии.
# 3. Напишите запрос, выводящий список студентов, обучающихся в Воронеже, с последующей сортировкой по идентификаторам университетов и курсам.
# 4. Напишите запрос, выводящий список предметов, на изучение которых отведено максимальное количество часов.
# 5. Напишите запрос, выполняющий вывод имен и фамилий студентов, место проживания которых не совпадает с городом, в котором находится их университет.
# 6. Напишите запрос, выводящий список университетов, расположенных в Москве и имеющих рейтинг больший, чем у ВГУ.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Ответы на задания раздела 2.8. Вложенные подзапросы.

from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
s1=select(func.max(student.c.stipend))
result=conn.execute(s1).scalar()
result
# Out:
# 250

# %%
#1

# Создание SQL-выражения подзапроса, который возвращает скаляр - одно число,
# поэтому здесь дополнительно применяем метод .scalar_subquery()
subq=select(func.max(student.c.stipend)).scalar_subquery()

# Используем SQL-выражение подзапроса в основном запросе
s=select(student.c.surname, student.c.stipend)
s=s.where(student.c.stipend==subq)
s=s.order_by(student.c.surname)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Белкин', 250), ('Блохина', 250), ('Вячеслав', 250), ('Ершов', 250), ('Жук', 250), ('Зайцева', 250), ('Казакова', 250), ('Кудряшов', 250), ('Мельникова', 250), ('Морозов', 250), ('Некрасова', 250), ('Никитин', 250), ('Панов', 250), ('Петров', 250), ('Петрова', 250), ('Пономарева', 250), ('Русаков', 250), ('Суханов', 250), ('Трофимов', 250), ('Щербакова', 250)]

# %%
#2
subq=select(func.avg(student.c.stipend)).scalar_subquery()

s=select(student.c.surname, student.c.stipend)
s=s.where(student.c.stipend>subq)
s=s.order_by(student.c.surname)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Агафонов', 150), ('Агафонов', 200), ('Аксенов', 200), ('Архипов', 180), ('Баранов', 220), ('Белкин', 250), ('Бирюков', 200), ('Блохина', 250), ('Борисова', 150), ('Валерия', 200), ('Веселов', 150), ('Вишнякова', 200), ('Владимиров', 200), ('Вячеслав', 250), ('Гордеев', 200), ('Гуляев', 150), ('Дементьева', 150), ('Дмитриев', 200), ('Дуб', 150), ('Ершов', 250), ('Ефимов', 200), ('Жданова', 200), ('Жук', 250), ('Жукова', 150), ('Жуковский', 150), ('Журавлев', 200), ('Зайцева', 250), ('Захаров', 150), ('Иванов', 150), ('Иванова', 200), ('Игнатьева', 200), ('Казакова', 250), ('Казакова', 150), ('Калашников', 200), ('Карпов', 200), ('Киселев', 210), ('Ковалев', 200), ('Колобов', 200), ('Кондрат', 200), ('Кондратьев', 150), ('Котов', 150), ('Кудравцев', 150), ('Кудряшов', 250), ('Кулаков', 150), ('Лапина', 150), ('Лихачева', 150), ('Лукин', 200), ('Медведев', 200), ('Мельникова', 250), ('Миронова', 200), ('Миронова', 200), ('Мишина', 150), ('Морозов', 250), ('Назаров', 150), ('Некрасова
# ...

# %%
#3 

# Создадим подапрос, который возвращает список id университетов Воронежа
subq=select(university.c.univ_id)
subq=subq.where(university.c.city=="Воронеж")

# Используем подзапрос в основном запросе с помощью функции .in_()
s=select(student.c.surname, student.c.univ_id)
s=s.where(student.c.univ_id.in_(subq))
result=conn.execute(s).fetchall()
print(result)
# Out:
# [('Иванов', 10), ('Петров', 10), ('Кузнецов', 10), ('Зайцева', 10), ('Белкин', 10), ('Соколова', 18), ('Семенова', 10), ('Сергеева', 10), ('Некрасова', 10), ('Игнатьева', 10), ('Кондрат', 18), ('Мельникова', 10), ('Мишина', 18), ('Агафонов', 10), ('Лихачева', 10), ('Жданова', 10), ('Валерия', 18), ('Суравьева', 18), ('Борисова', 10), ('Дмитриев', 10), ('Карпов', 10), ('Аксенов', 10), ('Федоров', 10), ('Бирюков', 10), ('Юдин', 18), ('Мамонтов', 18), ('Журавлев', 18), ('Павлов', 10), ('Лукин', 10)]

# %%
#4

subq=select(func.max(subject.c.hour)).scalar_subquery()

s=select(subject)
s=s.where(subject.c.hour==subq)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(23, 'Теория вероятностей и математическая статистика', 72, 4)]

# %%
#5

subq=select(university.c.city)
subq=subq.where(university.c.univ_id==student.c.univ_id).scalar_subquery()

s=select(student.c.name, student.c.surname)
s=s.where(student.c.city != (subq))
result=conn.execute(s).fetchall()
print(result, len(result))
# Out:
# [('Иван', 'Иванов'), ('Петр', 'Петров'), ('Борис', 'Кузнецов'), ('Ольга', 'Зайцева'), ('Елизавета', 'Дуб'), ('Вера', 'Кудряшова'), ('Вера', 'Журавлева'), ('Софья', 'Дементьева'), ('Пелагея', 'Рожкова'), ('Ия', 'Соколова'), ('Вероника', 'Семенова'), ('Ирина', 'Пак'), ('Оксана', 'Жук'), ('Вероника', 'Некрасова'), ('Оксана', 'Игнатьева'), ('Ольга', 'Казакова'), ('Елена', 'Шубина'), ('Анна', 'Миронова'), ('Синицин', 'Кондрат'), ('Алина', 'Пономарева'), ('Лидия', 'Одинцова'), ('Рукижат', 'Гуляева'), ('Зинаида', 'Игнатова'), ('Дарья', 'Мельникова'), ('Светлана', 'Мишина'), ('Василий', 'Агафонов'), ('Анжелика', 'Афанасьева'), ('Василиса', 'Фролова'), ('Нина', 'Лихачева'), ('Элеонора', 'Лапина'), ('Ирина', 'Сорокина'), ('Галина', 'Шашкова'), ('Мария', 'Казакова'), ('Фекла', 'Жукова'), ('Виктория', 'Зимина'), ('Ирина', 'Жданова'), ('Овчинникова', 'Валерия'), ('Кира', 'Костина'), ('Ираида', 'Блохина'), ('Светлана', 'Мельникова'), ('Агата', 'Щербакова'), ('Оксана', 'Васильева'), ('Валерия', 'Со
# ...

# %%
#6

subq=select(university.c.rating)
subq=subq.where(university.c.univ_name=="ВГУ").scalar_subquery()

s=select(university)
s=s.where(university.c.city=="Москва")
s=s.where(university.c.rating > subq)
result=conn.execute(s).fetchall()
print(result)
# Out:
# [(22, 'МГУ', 606, 'Москва'), (44, 'ФинУ', 330, 'Москва'), (45, 'МГТУ', 372, 'Москва')]

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 1 ноября 2021 года; ФРФТ20-2; консультация онлайн<br>
# 4 ноября 2021 года; ФРФТ20-1; консультация онлайн
#
# ## 2.9. Формирование связанных подзапросов
#
# В подзапросе можно ссылаться на таблицу, имя которой указано в предложении FROM основного (внешнего) запроса. Такие подзапросы называются связанными. Связанный подзапрос выполняется по одному разу для каждой строки таблицы внешнего запроса, а именно:
# - выбирается строка из таблицы, имя которой указано во внешнем запросе;
# - выполняется подзапрос, и полученное в результате его выполнения значение применяется для анализа этой строки в условии предложения WHERE внешнего запроса;
# - по результату оценки этого условия принимается решение о включении или невключении строки в состав выходных данных;
# - процедура повторяется для следующей строки таблицы внешнего запроса.
#
# Пример.
# Выбрать сведения обо всех предметах обучения, по которым проводился экзамен 2 июня 2021 г.
# ```
# select subj_name from subject su
# 	where "2021-06-02" in (
# 		select date(exam_date) from exam_marks ex where su.subj_id=ex.subj_id);
# ```
# В подзапросе использована функция *date()* для преобразования формата даты-времени к формату даты. В приведенном запросе SU и EX являются псевдонимами (алиасами), т. е. специально вводимыми именами, которые могут быть использованы в данном запросе вместо настоящих имен. В приведенном примере они
# используются вместо имен таблиц SUBJECT и EXAM_MARKS.
#
# Эту же задачу можно решить с помощью операции соединения таблиц:
# ```
# select distinct first.subj_id, subj_name, hour, semester
# 	from subject first, exam_marks second
#     where first.subj_id = second.subj_id
#     AND second.exam_date like "2021-06-02%";
# ```
# В этом выражении алиасами таблиц являются имена *first* и *second*.
#
# Можно использовать подзапросы, связывающие таблицу со своей собственной копией. Например, надо найти идентификаторы, фамилии и стипендии студентов, получающих стипендию выше средней на курсе, на котором они учатся:
# ```
# select student_id, name, stipend
# 	from student e1 where e1.stipend > (
# 		select avg(stipend) from student e2 where e1.kurs=e2.kurs);
# ```
# Тот же результат можно получить с помощью следующего запроса:
#
# ```
# select student_id, name, stipend
# 	from student e1, (select kurs, avg(stipend) as avg_stipend
#         from student e2 group by e2.kurs) e3
# 	where e1.stipend>e3.avg_stipend and e1.kurs=e3.kurs;
# ```
# Обратите внимание — второй запрос должен выполниться быстрее. Дело в том, что в первом варианте запроса агрегирующая функция *avg()* выполняется над таблицей, указанной в подзапросе, для
# каждой строки внешнего запроса. В другом варианте вторая таблица (алиас *e2*) обрабатывается агрегирующей функцией один раз, в результате чего формируется вспомогательная таблица (в запросе
# она имеет алиас *e3*), со строками которой затем соединяются строки первой таблицы (алиас *e1*).

# %% [markdown]
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос для получения списка студентов, которые учатся в своём городе.
# 2. Напишите запрос для получения списка преподавателей, работающих не в своём городе, с последующей сортировкой по идентификаторам университетов и городам проживания преподавателей.
# 3. Напишите запрос для получения списка студентов, получающих стипендию, превосходящую среднее значение стипендии на своём курсе.
# 4. Напишите запрос для получения списка университетов, в которых учится более 10 студентов, с последующей сортировкой по рейтингам.
# 5. Напишите запрос для получения списка отличников (студентов, получивших только отличные оценки), с последующей сортировкой по идентификаторам университетов и курсам.
# 6. Напишите запрос, выполняющий вывод списка студентов, средняя оценка которых превышает 4 балла.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Ответы на задания раздела 2.9. Формирование связанных подзапросов.

from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func, alias
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1
subq=select(university.c.city)
subq=subq.where(university.c.univ_id==student.c.univ_id).scalar_subquery()

s=select(student)
s=s.where(student.c.city == subq)

result=conn.execute(s).fetchall()
print(s)
result
# Out:
# SELECT student.student_id, student.surname, student.name, student.stipend, student.kurs, student.city, student.birthday, student.univ_id
# FROM student
# WHERE student.city = (SELECT university.city
# FROM university
# WHERE university.univ_id = student.univ_id)
# [(6, 'Сидоров', 'Вадим', 150, 4, 'Москва', datetime.datetime(1999, 6, 7, 0, 0), 22),
#  (32, 'Котов', 'Павел', 150, 5, 'Белгород', datetime.datetime(2001, 2, 28, 0, 0), 14),
#  (55, 'Белкин', 'Вадим', 250, 5, 'Воронеж', datetime.datetime(2000, 1, 7, 0, 0), 10),
#  (200, 'Баранов', 'Александр', 220, 2, 'Москва', datetime.datetime(2001, 8, 18, 0, 0), 44),
#  (203, 'Петрова', 'Екатерина', 250, 4, 'Белгород', datetime.datetime(2001, 5, 21, 0, 0), 14),
#  (207, 'Миронова', 'Федор', 200, 3, 'Москва', datetime.datetime(2002, 4, 15, 0, 0), 45),
#  (265, 'Павлов', 'Андрей', 0, 3, 'Воронеж', datetime.datetime(2000, 11, 5, 0, 0), 10),
#  (654, 'Лукин', 'Артем', 200, 3, 'Воронеж', datetime.datetime(2001, 12, 1, 0, 0), 10)]

# %%
#2
subq=select(university.c.city)
subq=subq.where(university.c.univ_id==lecturer.c.univ_id).scalar_subquery()

s=select(lecturer)
s=s.where(lecturer.c.city!=subq)

print(s)

result=conn.execute(s).fetchall()
result[:5]
# Out:
# SELECT lecturer.lecturer_id, lecturer.surname, lecturer.name, lecturer.city, lecturer.univ_id
# FROM lecturer
# WHERE lecturer.city != (SELECT university.city
# FROM university
# WHERE university.univ_id = lecturer.univ_id)
# [(1, 'Лукия', 'Сафонова', 'Смоленск', 46),
#  (2, 'Юлия', 'Зайцева', 'Белгород', 10),
#  (3, 'Акулина', 'Мамонтова', 'Троицк (Моск.)', 11),
#  (4, 'Оксана', 'Богданова', 'Всеволожск', 18),
#  (5, 'Нинель', 'Брагина', 'Кижи', 48)]

# %%
#3

st1=student.alias("st1")2
st2=student.alias("st2")

subq=select(func.avg(st1.c.stipend).label("avg_stipend"))
subq=subq.where(st2.c.kurs==st1.c.kurs)

s=select(st2)
s=s.where(st2.c.stipend>subq)

result=conn.execute(s).fetchall()
result[:5]

print(s, "\n\n", len(result))
result[:5]
# Out:
# SELECT st2.student_id, st2.surname, st2.name, st2.stipend, st2.kurs, st2.city, st2.birthday, st2.univ_id
# FROM student AS st2
# WHERE st2.stipend > (SELECT avg(st1.stipend) AS avg_stipend
# FROM student AS st1
# WHERE st2.kurs = st1.kurs)
#
#  68
# [(1, 'Иванов', 'Иван', 150, 1, 'Орел', datetime.datetime(2002, 12, 3, 0, 0), 10),
#  (3, 'Петров', 'Петр', 200, 3, 'Курск', datetime.datetime(2000, 12, 1, 0, 0), 10),
#  (12, 'Зайцева', 'Ольга', 250, 2, 'Липецк', datetime.datetime(2001, 5, 1, 0, 0), 10),
#  (32, 'Котов', 'Павел', 150, 5, 'Белгород', datetime.datetime(2001, 2, 28, 0, 0), 14),
#  (55, 'Белкин', 'Вадим', 250, 5, 'Воронеж', datetime.datetime(2000, 1, 7, 0, 0), 10)]

# %%
#4

subq=select(func.count(student.c.student_id))
subq=subq.where(student.c.univ_id==university.c.univ_id).scalar_subquery()

s=select(university)
s=s.where(subq>10)
s=s.order_by(university.c.rating)

print(s, "\>", s.compile().params)

conn.execute(s).fetchall()
# Out:
# SELECT university.univ_id, university.univ_name, university.rating, university.city
# FROM university
# WHERE (SELECT count(student.student_id) AS count_1
# FROM student
# WHERE student.univ_id = university.univ_id) > :param_1 ORDER BY university.rating \> {'param_1': 10}
# [(10, 'ВГУ', 296, 'Воронеж'),
#  (14, 'БГУ', 326, 'Белгород'),
#  (44, 'ФинУ', 330, 'Москва'),
#  (22, 'МГУ', 606, 'Москва')]

# %%
#5

subq=select(func.min(exam_marks.c.mark))
subq=subq.where(exam_marks.c.student_id==student.c.student_id).scalar_subquery()

s=select(student.c.surname, student.c.name, student.c.stipend, student.c.kurs, student.c.univ_id)
s=s.where(subq==5)
s=s.order_by(student.c.univ_id, student.c.kurs)

print(s, "\>", s.compile().params)

conn.execute(s).fetchall()
# Out:
# SELECT student.surname, student.name, student.stipend, student.kurs, student.univ_id
# FROM student
# WHERE (SELECT min(exam_marks.mark) AS min_1
# FROM exam_marks
# WHERE exam_marks.student_id = student.student_id) = :param_1 ORDER BY student.univ_id, student.kurs \> {'param_1': 5}
# [('Борисова', 'Марина', 150, 1, 10),
#  ('Кузнецов', 'Борис', 0, 2, 10),
#  ('Жданова', 'Ирина', 200, 3, 10),
#  ('Белкин', 'Вадим', 250, 5, 10),
#  ('Мельникова', 'Светлана', 250, 4, 15),
#  ('Блохина', 'Ираида', 250, 3, 22),
#  ('Лапина', 'Элеонора', 150, 3, 45)]

# %%
#6

subq=select(func.avg(exam_marks.c.mark))
subq=subq.where(student.c.student_id==exam_marks.c.student_id).scalar_subquery()

s=select(student.c.name, student.c.surname)
s=s.where(subq>4)

print(s, "\>", s.compile().params)

conn.execute(s).fetchall()
# Out:
# SELECT student.name, student.surname
# FROM student
# WHERE (SELECT avg(exam_marks.mark) AS avg_1
# FROM exam_marks
# WHERE student.student_id = exam_marks.student_id) > :param_1 \> {'param_1': 4}
# [('Борис', 'Кузнецов'),
#  ('Вадим', 'Белкин'),
#  ('Элеонора', 'Лапина'),
#  ('Ирина', 'Жданова'),
#  ('Ираида', 'Блохина'),
#  ('Светлана', 'Мельникова'),
#  ('Марина', 'Борисова')]

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 8 ноября 2021 года<br>
# ФРФТ20-2, ФРФТ20-2; семинарское занятие онлайн
#
# ## 2.10. Связанные подзапросы в HAVING
#
# В разделе 2.4 указывалось, что предложение GROUP BY позволяет группировать выводимые SELECT-запросом записи по значению некоторого поля. Использование предложения HAVING позволяет при выводе осуществлять фильтрацию таких групп. Предикат предложения HAVING оценивается не для каждой строки результата, а для каждой группы выходных записей, сформированной предложением GROUP BY внешнего запроса.
#
# Пусть, например, необходимо по данным из таблицы EXAM_MARKS определить сумму полученных студентами оценок (значений поля MARK), сгруппировав значения оценок по датам экзаменов и исключив те дни, когда число студентов, сдававших в течение дня экзамены, было больше трёх:
# ```
# SELECT EXAM_DATE, SUM(MARK)
#     FROM EXAM_MARKS A
#     GROUP BY EXAM_DATE
#     HAVING 3 < (SELECT COUNT(MARK)
#         FROM EXAM_MARKS B
#         WHERE A.EXAM_DATE = B.EXAM_DATE);
# ```
# Подзапрос вычисляет количество строк, у которых значения поля EXAM_DATE (дата экзамена) совпадает с датой, для которой сформирована очередная группа основного запроса.
#
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос с подзапросом для получения всех оценок студента с фамилией Иванов. Предположим, что его персональный номер неизвестен. Всегда ли такой запрос будет корректным?
# 2. Напишите запрос, выбирающий имена и фамилии всех студентов, имеющих по предмету c идентификатором 10 балл выше общего среднего балла.
# 3. Напишите запрос, выполняющий вывод идентификаторов студентов и количества предметов, по которым экзаменовался каждый студент, сдававший более двух предметов.
# 4. Напишите запрос со связанным подзапросом для вывода имен и идентификаторов студентов, у которых стипендия совпадает с максимальным значением стипендии для города, в котором живет студент.
# 5. Напишите запрос, который позволяет вывести имена и идентификаторы всех студентов, о которых точно известно, что они проживают в городе, где нет ни одного университета.
# 6. Напишите два запроса, которые позволяют вывести имена и идентификаторы всех студентов, о которых точно известно, что они проживают не в том городе, где расположен их университет: один запрос с использованием связанного подзапроса, а другой — с использованием соединения.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Ответы на задания раздела 2.10. "Связанные подзапросы в HAVING".

from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func, alias
from pprint import pprint
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
# Запрос из примера
a=exam_marks.alias("A")
b=exam_marks.alias("B")

subq=select(func.count(b.c.mark))
subq=subq.where(a.c.exam_date==b.c.exam_date).scalar_subquery()

s=select(a.c.exam_date, func.sum(a.c.mark))
s=s.group_by(a.c.exam_date)
s=s.having(subq>3)

#print(s, s.compile().params)

result=conn.execute(s).fetchall()
pprint(result)
# Out:
# [(datetime.datetime(2019, 5, 29, 0, 0), 24),
#  (datetime.datetime(2020, 5, 26, 0, 0), 18),
#  (datetime.datetime(2021, 6, 2, 0, 0), 12)]

# %%
#1
subq=select(student.c.student_id)
subq=subq.where(student.c.surname=="Иванов").scalar_subquery()

s=select(exam_marks)
s=s.where(exam_marks.c.student_id==subq)

#print(s, s.compile().params)

conn.execute(s).fetchall()
# Out:
# SELECT exam_marks.exam_id, exam_marks.student_id, exam_marks.subj_id, exam_marks.mark, exam_marks.exam_date
# FROM exam_marks
# WHERE exam_marks.student_id = (SELECT student.student_id
# FROM student
# WHERE student.surname = :surname_1) {'surname_1': 'Иванов'}
# [(29, 1, 43, 1, datetime.datetime(2020, 10, 24, 0, 0))]

# %%
#2
subq=select(func.avg(exam_marks.c.mark)).scalar_subquery()

s=select(student.c.name, student.c.surname)
s=s.where(student.c.student_id==exam_marks.c.student_id)
s=s.where(exam_marks.c.subj_id==10)
s=s.where(exam_marks.c.mark>subq)

print(s)

result=conn.execute(s).fetchall()
pprint(result)
# Out:
# SELECT student.name, student.surname
# FROM student, exam_marks
# WHERE student.student_id = exam_marks.student_id AND exam_marks.subj_id = :subj_id_1 AND exam_marks.mark > (SELECT avg(exam_marks.mark) AS avg_1
# FROM exam_marks)
# [('Синицин', 'Кондрат'),
#  ('Светлана', 'Мельникова'),
#  ('Анатолий', 'Антонов'),
#  ('Павел', 'Котов'),
#  ('Вадим', 'Белкин'),
#  ('Ольга', 'Зайцева')]

# %%
#3
a=exam_marks.alias("A")
b=exam_marks.alias("B")

subq=select(func.count(b.c.subj_id))
subq=subq.where(a.c.student_id==b.c.student_id).scalar_subquery()

s=select(a.c.student_id, func.count(a.c.subj_id))
s=s.group_by(a.c.student_id)
s=s.having(subq>1)

#print(s)

result=conn.execute(s).fetchall()
pprint(result)
# Out:
# [(12, 2), (55, 2), (76, 2), (85, 2), (101, 2), (128, 2)]

# %%
#4
a=student.alias("A")
b=student.alias("B")

subq=select(func.max(b.c.stipend))
subq=subq.where(b.c.city==a.c.city).scalar_subquery()

s=select(a.c.student_id, a.c.name)
s=s.where(a.c.stipend==subq)
#print(s)

result=conn.execute(s).fetchall()
print(result, len(result))
# Out:
# [(12, 'Ольга'), (55, 'Вадим'), (56, 'Елизавета'), (57, 'Вера'), (58, 'Вера'), (59, 'Софья'), (61, 'Ия'), (62, 'Вероника'), (64, 'Оксана'), (66, 'Вероника'), (67, 'Оксана'), (68, 'Ольга'), (69, 'Елена'), (70, 'Анна'), (71, 'Синицин'), (72, 'Алина'), (73, 'Лидия'), (74, 'Рукижат'), (75, 'Зинаида'), (76, 'Дарья'), (77, 'Светлана'), (79, 'Анжелика'), (80, 'Василиса'), (81, 'Нина'), (82, 'Элеонора'), (83, 'Ирина'), (84, 'Галина'), (85, 'Мария'), (86, 'Фекла'), (87, 'Виктория'), (88, 'Ирина'), (89, 'Овчинникова'), (90, 'Кира'), (91, 'Ираида'), (92, 'Светлана'), (93, 'Агата'), (94, 'Оксана'), (95, 'Валерия'), (97, 'Анжела'), (98, 'Фаина'), (99, 'Марина'), (100, 'Самуил'), (101, 'Евгений'), (102, 'Касьян'), (103, 'Владислав'), (104, 'Герасим'), (105, 'Анатолий'), (106, 'Владимир'), (107, 'Кирилл'), (108, 'Икром'), (109, 'Павел'), (110, 'Константин'), (111, 'Лука'), (113, 'Валерий'), (114, 'Арсений'), (115, 'Иннокентий'), (117, 'Константин'), (118, 'Николай'), (119, 'Архип'), (120, 'Радмил'),
# ...

# %%
#5
subq=select(university.c.city)

s=select(student.c.student_id, student.c.name)
s=s.where(student.c.city.notin_(subq))
#print(s)

result=conn.execute(s).fetchall()
print(result)
# Out:
# [(1, 'Иван'), (3, 'Петр'), (10, 'Борис'), (12, 'Ольга'), (56, 'Елизавета'), (57, 'Вера'), (58, 'Вера'), (59, 'Софья'), (60, 'Пелагея'), (61, 'Ия'), (62, 'Вероника'), (63, 'Ирина'), (64, 'Оксана'), (66, 'Вероника'), (67, 'Оксана'), (68, 'Ольга'), (69, 'Елена'), (70, 'Анна'), (71, 'Синицин'), (72, 'Алина'), (73, 'Лидия'), (74, 'Рукижат'), (76, 'Дарья'), (77, 'Светлана'), (78, 'Василий'), (79, 'Анжелика'), (80, 'Василиса'), (81, 'Нина'), (82, 'Элеонора'), (83, 'Ирина'), (84, 'Галина'), (85, 'Мария'), (86, 'Фекла'), (87, 'Виктория'), (88, 'Ирина'), (89, 'Овчинникова'), (90, 'Кира'), (91, 'Ираида'), (92, 'Светлана'), (93, 'Агата'), (94, 'Оксана'), (95, 'Валерия'), (97, 'Анжела'), (98, 'Фаина'), (99, 'Марина'), (100, 'Самуил'), (101, 'Евгений'), (102, 'Касьян'), (103, 'Владислав'), (104, 'Герасим'), (105, 'Анатолий'), (106, 'Владимир'), (107, 'Кирилл'), (108, 'Икром'), (109, 'Павел'), (110, 'Константин'), (111, 'Лука'), (112, 'Софон'), (113, 'Валерий'), (114, 'Арсений'), (115, 'Иннокентий'
# ...

# %%
# 6a
subq=select(university.c.city)
subq=subq.where(university.c.univ_id==student.c.univ_id).scalar_subquery()

s=select(student.c.student_id, student.c.name)
s=s.where(student.c.city!=subq)
print(s)

result=conn.execute(s).fetchall()
print(result, len(result))
# Out:
# SELECT student.student_id, student.name
# FROM student
# WHERE student.city != (SELECT university.city
# FROM university
# WHERE university.univ_id = student.univ_id)
# ...

# %%
#6b
s=select(student.c.student_id, student.c.name)
s=s.where(student.c.univ_id==university.c.univ_id)
s=s.where(student.c.city!=university.c.city)
#print(s)

result=conn.execute(s).fetchall()
print(result[:10], len(result))
# Out:
# [(1, 'Иван'), (3, 'Петр'), (10, 'Борис'), (12, 'Ольга'), (56, 'Елизавета'), (57, 'Вера'), (58, 'Вера'), (59, 'Софья'), (60, 'Пелагея'), (61, 'Ия')] 102

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. Электронный ресурс. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. Электронный ресурс. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 15 ноября 2021 года<br>
# ФРФТ20-2, ФРФТ20-1; вебинар
#
# ## 2.11. Использование оператора EXISTS
#
# Используемое в SQL ключевое слово EXISTS (существует) представляет собой предикат, принимающий значение истина или ложь. Используя подзапросы в качестве аргумента, этот оператор оценивает результат выполнения подзапроса как истинный, если этот подзапрос генерирует выходные данные, то есть в случае существования (возврата) хотя бы одного найденного значения. В противном случае результат подзапроса — ложный. Оператор EXISTS не может принимать значение неизвестно).
#
# Пусть, например, нужно извлечь из таблицы EXAM_MARKS данные о студентах, получивших хотя бы одну неудовлетворительную оценку:
# ```
# SELECT DISTINCT STUDENT_ID
# FROM EXAM_MARKS A
# WHERE EXISTS
# (SELECT *
# FROM EXAM_MARKS B
# WHERE MARK < 3
# AND B.STUDENT_ID=A.STUDENT_ID);
# ```
# При использовании связанных подзапросов предложение EXISTS анализирует каждую строку таблицы, на которую имеется ссылка во внешнем запросе. Главный запрос получает строки-кандидаты на проверку условия. Для каждой строки-кандидата выполняется подзапрос. Как только при выполнении подзапроса находится строка, в которой значение в столбце MARK удовлетворяет условию, его выполнение прекращается и возвращается значение истина внешнему запросу, который затем анализирует свою строку-кандидата.
#
# Например, требуется получить идентификаторы предметов обучения, экзамены по которым сдавались не одним, а несколькими студентами:
# ```
# SELECT DISTINCT SUBJ_ID
# FROM EXAM_MARKS A
# WHERE EXISTS
# (SELECT *
# FROM EXAM_MARKS B
# WHERE A.SUBJ_ID = B.SUBJ_ID
# AND A.STUDENT_ID <> B.STUDENT_ID);
# ```
# Часто EXISTS применяется с оператором NOT (по-русски NOT EXISTS интерпретируется, как “не существует. . .”). Если предыдущий запрос сформулировать следующим образом: “Найти идентификаторы предметов обучения, которые сдавались одним и только одним студентом (другими словами, для которых не существует другого сдававшего студента),” то достаточно просто поставить NOT перед EXISTS.
#
# Возможности применения вложенных запросов весьма разнообразны. Например, пусть из таблицы STUDENT требуется извлечь строки для каждого студента, сдавшего более одного предмета:
# ```
# SELECT *
# FROM STUDENT FIRST
# WHERE EXISTS
# (SELECT SUBJ_ID
# FROM EXAM_MARKS SECOND
# WHERE FIRST.STUDENT_ID = SECOND.STUDENT_ID
# GROUP BY SUBJ_ID
# HAVING COUNT(SUBJ_ID) > 1);
# ```
#
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос с EXISTS, позволяющий вывести данные обо всех фамилиях и именах студентов обучающихся в вузах, имеющих рейтинг выше 400. Результат упорядочить по фамилии и имени.
# 2. Напишите предыдущий запрос, используя соединения.
# 3. Напишите запрос с EXISTS, выбирающий сведения о каждом студенте, для которого в городе его проживания имеется хотя бы один университет, в котором он не учится.
# 4. Напишите запрос, выбирающий из таблицы SUBJECT данные о названиях предметов обучения, экзамены по которым сданы более чем одним студентом.
# 5. Напишите запрос для получения списка городов проживания студентов, в которых есть хотя бы один университет.
# 6. Напишите запрос для получения списка городов проживания студентов, в которых нет ни одного университета.
# 7. Напишите запрос для получения списка предметов, для которых не назначено ни одного преподавателя.
# 8. Напишите запрос для получения списка предметов, изучаемых в течение одного семестра.
# 9. Напишите запрос для получения списка предметов, изучаемых более чем в одном семестре.
# 10. Напишите запрос для получения списка университетов, в которых не работает ни один преподаватель.
# 11. Напишите запрос для получения списка университетов, в которых не учится ни один студент.
# 12. Напишите запрос для получения списка предметов, по которым на экзаменах не получено ни одной неудовлетворительной оценки.
# 13. Напишите запрос для получения списка предметов, по которым на экзаменах получена хотя бы одна неудовлетворительная оценка.
# 14. Напишите запрос для получения списка студентов, не получивших на экзаменах ни одной неудовлетворительной оценки.
# 15. Напишите запрос для получения списка студентов, получивших на экзаменах хотя бы одну неудовлетворительную оценку.
# 16. Напишите запрос, выполняющий вывод имен и фамилий студентов, получивших хотя бы одну отличную оценку.
# 17. Напишите запрос, выполняющий вывод имен и фамилий студентов, не получивших ни одной отличной оценки.
# 18. Напишите запрос, выполняющий вывод количества студентов, не имеющих ни одной оценки.
# 19. Напишите запрос, выполняющий вывод количества студентов, имеющих только отличные оценки.
# 20. Напишите запрос, выполняющий вывод количества студентов, имеющих хотя бы одну неудовлетворительную оценку и проживающих в городе, не совпадающем с городом их университета.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Решение заданий раздела 2.11 "Использование оператора EXISTS"
from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func, alias, exists
from pprint import pprint
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %%
#1 Напишите запрос с EXISTS, позволяющий вывести данные обо всех фамилиях и именах студентов обучающихся в вузах,
#имеющих рейтинг выше 400. Результат упорядочить по фамилии и имени.

A=student.alias("A")
B=university.alias("B")

ex=exists().where(B.c.univ_id==A.c.univ_id)
ex=ex.where(B.c.rating>400)

s=select(A.c.student_id, A.c.surname, A.c.name)
s=s.where(ex)
s=s.order_by(A.c.surname, A.c.name)

print(s, s.compile().params["rating_1"], "\n\n")

result=conn.execute(s).fetchall()
for i, item in enumerate(result):
    print(i, item)
# Out:
# SELECT "A".student_id, "A".surname, "A".name
# FROM student AS "A"
# WHERE EXISTS (SELECT *
# FROM university AS "B"
# WHERE "B".univ_id = "A".univ_id AND "B".rating > :rating_1) ORDER BY "A".surname, "A".name 400
#
#
# 0 (105, 'Антонов', 'Анатолий')
# 1 (201, 'Архипов', 'Андрей')
# 2 (79, 'Афанасьева', 'Анжелика')
# 3 (91, 'Блохина', 'Ираида')
# 4 (94, 'Васильева', 'Оксана')
# 5 (122, 'Гордеев', 'Филипп')
# 6 (120, 'Горский', 'Радмил')
# 7 (74, 'Гуляева', 'Рукижат')
# 8 (141, 'Ершов', 'Митрофан')
# 9 (136, 'Ефимов', 'Яков')
# 10 (133, 'Жуковский', 'Юрий')
# 11 (205, 'Иванова', 'Мария')
# 12 (75, 'Игнатова', 'Зинаида')
# 13 (85, 'Казакова', 'Мария')
# 14 (115, 'Колобов', 'Иннокентий')
# 15 (130, 'Кудряшов', 'Роман')
# 16 (114, 'Панов', 'Арсений')
# 17 (276, 'Петров', 'Антон')
# 18 (102, 'Петров', 'Касьян')
# 19 (6, 'Сидоров', 'Вадим')
# 20 (147, 'Симонов', 'Семен')

# %%
# 2 Напишите предыдущий запрос, используя соединения.

A=student.alias("A")
B=university.alias("B")

s=select(A.c.student_id, A.c.surname, A.c.name)
s=s.where(B.c.univ_id==A.c.univ_id)
s=s.where(B.c.rating>400)
s=s.order_by(A.c.surname, A.c.name)

print(s, s.compile().params, "\n\n")

result=conn.execute(s).fetchall()

for k, item in enumerate(result):
    print(k,item)
# Out:
# SELECT "A".student_id, "A".surname, "A".name
# FROM student AS "A", university AS "B"
# WHERE "B".univ_id = "A".univ_id AND "B".rating > :rating_1 ORDER BY "A".surname, "A".name {'rating_1': 400}
#
#
# 0 (105, 'Антонов', 'Анатолий')
# 1 (201, 'Архипов', 'Андрей')
# 2 (79, 'Афанасьева', 'Анжелика')
# 3 (91, 'Блохина', 'Ираида')
# 4 (94, 'Васильева', 'Оксана')
# 5 (122, 'Гордеев', 'Филипп')
# 6 (120, 'Горский', 'Радмил')
# 7 (74, 'Гуляева', 'Рукижат')
# 8 (141, 'Ершов', 'Митрофан')
# 9 (136, 'Ефимов', 'Яков')
# 10 (133, 'Жуковский', 'Юрий')
# 11 (205, 'Иванова', 'Мария')
# 12 (75, 'Игнатова', 'Зинаида')
# 13 (85, 'Казакова', 'Мария')
# 14 (115, 'Колобов', 'Иннокентий')
# 15 (130, 'Кудряшов', 'Роман')
# 16 (114, 'Панов', 'Арсений')
# 17 (276, 'Петров', 'Антон')
# 18 (102, 'Петров', 'Касьян')
# 19 (6, 'Сидоров', 'Вадим')
# 20 (147, 'Симонов', 'Семен')

# %%
#3 Напишите запрос с EXISTS, выбирающий сведения о каждом студенте, 
#для которого в городе его проживания имеется хотя бы один университет, в котором он не учится.

A=student.alias("A")
B=university.alias("B")

ex=exists().where(B.c.univ_id != A.c.univ_id)
ex=ex.where(B.c.city==A.c.city)

s=select(A.c.student_id, A.c.surname, A.c.name, A.c.city)
s=s.where(ex)

print(s)

result=conn.execute(s).fetchall()
print(len(result))
result
# Out:
# SELECT "A".student_id, "A".surname, "A".name, "A".city
# FROM student AS "A"
# WHERE EXISTS (SELECT *
# FROM university AS "B"
# WHERE "B".univ_id != "A".univ_id AND "B".city = "A".city)
# 9
# [(6, 'Сидоров', 'Вадим', 'Москва'),
#  (55, 'Белкин', 'Вадим', 'Воронеж'),
#  (75, 'Игнатова', 'Зинаида', 'Ростов'),
#  (120, 'Горский', 'Радмил', 'Томск'),
#  (200, 'Баранов', 'Александр', 'Москва'),
#  (207, 'Миронова', 'Федор', 'Москва'),
#  (265, 'Павлов', 'Андрей', 'Воронеж'),
#  (276, 'Петров', 'Антон', 'Ульяновск'),
#  (654, 'Лукин', 'Артем', 'Воронеж')]

# %%
#4 Напишите запрос, выбирающий из таблицы SUBJECT данные о названиях предметов обучения,
# экзамены по которым сданы более чем одним студентом.

A=subject.alias("A")
B=exam_marks.alias("B")

subq=select(B.c.subj_id, func.count(B.c.student_id))
subq=subq.where(A.c.subj_id==B.c.subj_id)
subq=subq.where(B.c.mark>2)
subq=subq.group_by(B.c.subj_id)
subq=subq.having(func.count(B.c.student_id)>1).scalar_subquery()

ex=exists(subq)

s=select(A.c.subj_name)
s=s.where(ex)

print(s)

result=conn.execute(s).fetchall()
result
# Out:
# SELECT "A".subj_name
# FROM subject AS "A"
# WHERE EXISTS (SELECT "B".subj_id, count("B".student_id) AS count_1
# FROM exam_marks AS "B"
# WHERE "A".subj_id = "B".subj_id AND "B".mark > :mark_1 GROUP BY "B".subj_id
# HAVING count("B".student_id) > :count_2)
# [('Английский язык',),
#  ('Информатика',),
#  ('История',),
#  ('Физика',),
#  ('Физкультура',)]

# %%
#5 Напишите запрос для получения списка городов проживания студентов, в которых есть хотя бы один университет.

S=student.alias("S")
U=university.alias("U")

ex=exists(U.c.univ_id).where(U.c.city==S.c.city)

s=select(S.c.city.distinct())
s=s.where(ex)

print(s)

result=conn.execute(s).fetchall()
print(result)
# Out:
# SELECT DISTINCT "S".city
# FROM student AS "S"
# WHERE EXISTS (SELECT "U".univ_id
# FROM university AS "U"
# WHERE "U".city = "S".city)
# [('Москва',), ('Белгород',), ('Воронеж',), ('Ростов',), ('Томск',), ('Ульяновск',)]

# %%
#6 Напишите запрос для получения списка городов проживания студентов, в которых нет ни одного университета.

S=student.alias("S")
U=university.alias("U")

ex=exists(U.c.univ_id).where(S.c.city==U.c.city)

s=select(func.distinct(S.c.city))
s=s.where(ex==False)

print(s)
result=conn.execute(s).fetchall()
print(result)
print(len(result))
# Out:
# SELECT distinct("S".city) AS distinct_1
# FROM student AS "S"
# WHERE (EXISTS (SELECT "U".univ_id
# FROM university AS "U"
# WHERE "S".city = "U".city)) = false
# ...

# %%
#7 Напишите запрос для получения списка предметов, для которых не назначено ни одного преподавателя.
S=subject.alias("S")
SL=subj_lect.alias("SL")

ex=exists(SL.c.lecturer_id).where(SL.c.subj_id==S.c.subj_id)

s=select(S.c.subj_name.distinct()).where(~ex)
print(s)

result=conn.execute(s).fetchall()
print(result)
print(len(result))
# Out:
# SELECT DISTINCT "S".subj_name
# FROM subject AS "S"
# WHERE NOT (EXISTS (SELECT "SL".lecturer_id
# FROM subj_lect AS "SL"
# WHERE "SL".subj_id = "S".subj_id))
# [('Обработка данных и моделирование в Excel',)]
# 1

# %%
#8 Напишите запрос для получения списка предметов, изучаемых в течение одного семестра

S1=subject.alias("S1")
S2=subject.alias("S2")

ex=exists().where(S1.c.subj_name==S2.c.subj_name)
ex=ex.where(S1.c.semester!=S2.c.semester)

s=select(S1.c.subj_name)
s=s.where(~ex)

print(s)
result=conn.execute(s).fetchall()
print(result)
print(len(result))
# Out:
# SELECT "S1".subj_name
# FROM subject AS "S1"
# WHERE NOT (EXISTS (SELECT *
# FROM subject AS "S2"
# WHERE "S1".subj_name = "S2".subj_name AND "S1".semester != "S2".semester))
# [('Информатика',), ('Программирование на языках Python и SQL',), ('Анализ данных',), ('ОБЖ',), ('Обработка данных и моделирование в Excel',), ('Физика',), ('Теория вероятностей и математическая статистика',), ('Математика',), ('История',), ('Английский язык',)]
# 10

# %%
#9 Напишите запрос для получения списка предметов, изучаемых более чем в одном семестре.

S1=subject.alias("S1")
S2=subject.alias("S2")

ex=exists().where(S1.c.subj_name==S2.c.subj_name)
ex=ex.where(S1.c.semester!=S2.c.semester)

s=select(S1.c.subj_name.distinct())
s=s.where(ex)

print(s)
result=conn.execute(s).fetchall()
print(result)
print(len(result))
# Out:
# SELECT DISTINCT "S1".subj_name
# FROM subject AS "S1"
# WHERE EXISTS (SELECT *
# FROM subject AS "S2"
# WHERE "S1".subj_name = "S2".subj_name AND "S1".semester != "S2".semester)
# [('Физкультура',)]
# 1

# %%
#10 Напишите запрос для получения списка университетов, в которых не работает ни один преподаватель.

L=lecturer.alias("L")
U=university.alias("U")

ex=exists().where(L.c.univ_id==U.c.univ_id)

s=select(U.c.univ_name)
s=s.where(~ex)

print(s)
result=conn.execute(s).fetchall()
print(result)
print(len(result))
# Out:
# SELECT "U".univ_name
# FROM university AS "U"
# WHERE NOT (EXISTS (SELECT *
# FROM lecturer AS "L"
# WHERE "L".univ_id = "U".univ_id))
# [('БГУ',), ('ФинУ',)]
# 2

# %%
#19. Напишите запрос, выполняющий вывод количества студентов, имеющих только отличные оценки.

EM1=student.alias("EM1")
EM2=exam_marks.alias("EM2")

ex1=exists().where(EM1.c.student_id==EM2.c.student_id)
ex1=ex1.where(EM2.c.mark<5)

ex2=exists().where(EM1.c.student_id==EM2.c.student_id)

s=select(func.count(EM1.c.student_id))
s=s.where(~ex1)
s=s.where(ex2)

print(s)

result=conn.execute(s).scalar()
print(result)
# Out:
# SELECT count("EM1".student_id) AS count_1
# FROM student AS "EM1"
# WHERE NOT (EXISTS (SELECT *
# FROM exam_marks AS "EM2"
# WHERE "EM1".student_id = "EM2".student_id AND "EM2".mark < :mark_1)) AND (EXISTS (SELECT *
# FROM exam_marks AS "EM2"
# WHERE "EM1".student_id = "EM2".student_id))
# 7

# %%
#20 Напишите запрос, выполняющий вывод количества студентов, имеющих хотя бы одну неудовлетворительную оценку 
# и проживающих в городе, не совпадающем с городом их университета.

S=student.alias("S")
EM=exam_marks.alias("EM")
U=university.alias("U")

ex1=exists().where(EM.c.mark<3).where(EM.c.student_id==S.c.student_id)
ex2=exists().where(S.c.univ_id==U.c.univ_id).where(S.c.city!=U.c.city)

s=select(func.count(S.c.student_id))
s=s.where(ex1).where(ex2)

print(s, s.compile().params)

result=conn.execute(s).scalar()
print(result)
# Out:
# SELECT count("S".student_id) AS count_1
# FROM student AS "S"
# WHERE (EXISTS (SELECT *
# FROM exam_marks AS "EM"
# WHERE "EM".mark < :mark_1 AND "EM".student_id = "S".student_id)) AND (EXISTS (SELECT *
# FROM university AS "U"
# WHERE "S".univ_id = "U".univ_id AND "S".city != "U".city)) {'mark_1': 3}
# 16

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 25 ноября 2021 года<br>
# ФРФТ20-2, ФРФТ20-1; вебинар
#
# ## 2.12. Соединение таблиц. Оператор JOIN
#
# Если в операторе SELECT после ключевого слова FROM указывается не одна, а две таблицы, то в результате выполнения запроса, в котором отсутствует предложение WHERE, каждая строка одной таблицы будет соединена с каждой строкой второй таблицы. Такая операция называется декартовым произведением, или полным соединением таблиц базы данных. Сама по себе эта операция не имеет практического значения, более того, при ошибочном использовании она может привести к неожиданным нештатным ситуациям, так как в этом случае в ответе на запрос количество записей будет равно произведению числа записей в соединяемых таблицах, т. е. может оказаться чрезвычайно большим. Соединение таблиц имеет смысл тогда, когда соединяются не все строки исходных таблиц, а только те, которые интересуют пользователя. Такое ограничение может быть осуществлено с помощью использования в запросеоответствующего условия в предложении WHERE. Таким образом, SQL позволяет выводить информацию из нескольких таблиц, связывая их по значениям определенных полей. Например, если необходимо получить фамилии студентов (таблица STUDENT) и для каждого студента — названия университетов (таблица UNIVERSITY), расположенных в городе, где живет студент, то необходимо получить все комбинации записей о студентах и университетах в обеих таблицах, в которых значение поля CITY совпадает. Это можно сделать с помощью следующего запроса:
# ```
# SELECT STUDENT.SURNAME, UNIVERSITY.UNIV_NAME, STUDENT.CITY
# FROM STUDENT, UNIVERSITY
# WHERE STUDENT.CITY = UNIVERSITY.CITY
# ```
# Рассмотренный пример соединения таблиц относятся к виду так называемого внутреннего (INNER) соединения. Приведенный выше запрос может быть записан иначе, с использованием ключевого слова JOIN:
# ```
# SELECT STUDENT.SURNAME, UNIVERSITY.UNIV_NAME, STUDENT.CITY
# FROM STUDENT INNER JOIN UNIVERSITY
# ON STUDENT.CITY = UNIVERSITY.CITY;
# ```
# Ключевое слово INNER в запросе может быть опущено, так как эта опция в операторе JOIN действует по умолчанию.
#
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите с помощью WHERE запрос для получения списка предметов вместе с фамилиями студентов, изучающих их на соответствующем курсе.
# 2. Напишите с помощью WHERE запрос, выполняющий вывод имен и фамилий студентов, имеющих положительные (тройки, четверки и пятерки) оценки.
# 3. Выполните второе задание с помощью IN и несвязанного вложенного подзапроса.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %%
# Решение заданий раздела 2.12 "Соединение таблиц. Оператор JOIN"
from sqlalchemy import MetaData, Table, create_engine, select, and_, or_, not_
from sqlalchemy.sql import func, alias, exists
from pprint import pprint
engine = create_engine('sqlite:///Data/Students.db')
metadata = MetaData()
metadata.reflect(bind=engine)
conn=engine.connect()
metadata.tables.keys()

exam_marks=Table("exam_marks", metadata, autoload=True, autoload_with="engine")
lecturer=Table("lecturer", metadata, autoload=True, autoload_with="engine")
student=Table("student", metadata, autoload=True, autoload_with="engine")
subj_lect=Table("subj_lect", metadata, autoload=True, autoload_with="engine")
subject=Table("subject", metadata, autoload=True, autoload_with="engine")
university=Table("university", metadata, autolad=True, autolad_with="engine")

# %% [markdown]
# <img src="./Img/Banner_1.png">
#
# 25 ноября 2021 года<br>
# ФРФТ20-2, ФРФТ20-1; вебинар
#
# ## 2.12.1. Операции соединения таблиц посредством ссылочной целостности
#
# Информация в таблицах STUDENT и EXAM_MARKS уже связана посредством поля STUDENT_ID. В таблице STUDENT поле STUDENT_ID является первичным ключом, а в таблице EXAM_MARKS — ссылающимся на него внешним ключом. Состояние связанных таким образом таблиц называется состоянием ссылочной целостности. В данном случае ссылочная целостность этих таблиц подразумевает, что каждому значению поля STUDENT_ID в таблице EXAM_MARKS обязательно соответствует такое же значение поля STUDENT_ID в таблице STUDENT. Другими словами, в таблице EXAM_MARKS не может быть записей, имеющих идентификаторы студентов, которых нет в таблице STUDENT. Стандартное применение операции соединения состоит в извлечении данных в терминах этой связи.
#
# Чтобы получить список фамилий студентов с полученными ими оценками и идентификаторами предметов, можно использовать следующий запрос:
# ```
# SELECT SURNAME, MARK, SUBJ_ID
#     FROM STUDENT, EXAM_MARKS
#     WHERE STUDENT.STUDENT_ID = EXAM_MARKS.STUDENT_ID;
# ```
# Тот же самый результат может быть получен при использовании в запросе для задания операции соединения таблиц ключевого слова
# JOIN. Запрос с оператором JOIN выглядит следующим образом:
# ```
# SELECT SURNAME, MARK
#     FROM STUDENT JOIN EXAM_MARKS
#     ON STUDENT.STUDENT_ID = EXAM_MARKS.STUDENT_ID;
# ```
# Хотя выше речь шла о соединении двух таблиц, можно сформировать запросы путем соединения более чем двух таблиц. Пусть требуется найти фамилии всех студентов, получивших неудовлетворительную оценку, вместе с названиями предметов обучения, по которым получена эта оценка.
# ```
# SELECT SUBJ_NAME, SURNAME, MARK
#     FROM STUDENT, SUBJECT, EXAM_MARKS
#     WHERE STUDENT.STUDENT_ID = EXAM_MARKS.STUDENT_ID
#     AND SUBJECT.SUBJ_ID = EXAM_MARKS.SUBJ_ID
#     AND EXAM_MARKS.MARK = 2
# ```
# То же самое с использованием оператора JOIN:
# ```
# SELECT SUBJ_NAME, SURNAME, MARK
#     FROM STUDENT JOIN EXAM_MARKS
#     ON STUDENT.STUDENT_ID = EXAM_MARKS.STUDENT_ID
#     JOIN SUBJECT
#     ON SUBJECT.SUBJ_ID = EXAM_MARKS.SUBJ_ID
#     WHERE MARK = 2
# ```
# <img src=./Img/icon-4017417__340.webp style="width:180px;height:160px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью DB Browser for SQLite</p>
#
# 1. Напишите запрос для получения списка университетов с указанием количества студентов, обучающихся на каждом курсе.
# 2. Напишите запрос для получения списка преподавателей с указанием их учебных предметов.
# 3. Напишите запрос для получения списка преподавателей с указанием нагрузки (суммарного количества часов) в каждом семестре.
# 4. Напишите запрос для получения списка университетов вместе с названиями преподаваемых в них предметов.
# 5. Напишите запрос для получения списка университетов с указанием суммарного количества аудиторных часов в каждом семестре.
# 6. Напишите запрос для получения списка университетов с указанием суммарного количества часов, отводимых на изучение каждого предмета.
# 7. Напишите запрос для получения списка преподавателей с указанием суммарного количества часов, отведенных для обучения каждому из предметов.
# 8. Напишите запрос для сортировки списка университетов по значениям максимальной стипендии, выплачиваемой студентам.
# 9. Напишите запрос для получения списка университетов вместе с фамилиями самых молодых студентов, обучаемых в них.
# 10. Напишите запрос для получения списка университетов вместе с фамилиями студентов, получающих максимальную для каждого университета стипендию.
# 11. Напишите запрос для получения списка студентов вместе с названиями предметов и оценками, полученными по каждому предмету на экзаменах.
# 12. Напишите запрос для получения списка предметов вместе с фамилиями студентов, получивших по данному предмету максимальную оценку.
# 13. Напишите запрос для получения списка предметов вместе с фамилиями студентов, сдававших экзамен по данному предмету последними.
# 14. Напишите запрос для получения списка предметов вместе с фамилиями студентов, первыми сдавших экзамен по данному предмету.
# 15. Напишите запрос для получения списка преподавателей, преподающих более одного предмета.
# 16. Напишите запрос для получения списка преподавателей, преподающих только один предмет.
# 17. Напишите запрос для получения списка студентов, сдававших экзамены по какому-либо из предметов более одного раза.
# 18. Напишите запрос для получения списка университетов вместе с фамилиями студентов, получивших хотя бы одну неудовлетворительную оценку.
# 19. Напишите запрос, выполняющий вывод имен и фамилий студентов, получивших хотя бы одну отличную оценку.
# 20. Напишите запрос, выполняющий вывод данных о предметах обучения, которые преподает Колесников.
# 21. Напишите запрос, выполняющий вывод имен и фамилий преподавателей, проводящих занятия на первом курсе.
# 22. Напишите запрос, выполняющий вывод имен и фамилий преподавателей, проводящих занятия в двух и более семестрах.
# 23. Напишите запрос, выполняющий вывод наименований предметов обучения, читаемых двумя или более преподавателями.
# 24. Напишите запрос, выполняющий вывод количества часов занятий, проводимых преподавателем Максимовым.
# 25. Напишите запрос, выполняющий вывод фамилий преподавателей, учебная нагрузка которых (количество учебных часов) превышает нагрузку преподавателя Лагутина.
# 26. Напишите запрос, выполняющий вывод фамилий преподавателей университетов с рейтингом, меньшим 200.
# 27. Напишите запрос, выполняющий вывод общего количества учебных часов занятий, проводимых для студентов первого курса ВГУ.
# 28. Напишите запрос, выполняющий вывод среднего количества учебных часов предметов обучения, преподаваемых студентам второго курса ВГУ.
# 29. Напишите запрос, выполняющий вывод списка фамилий студентов, имеющих две или более отличных оценок в каждом семестре.
# 30. Приведите как можно больше формулировок запроса “Получить фамилии студентов, сдававших экзамен по информатике”.
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>

# %% [markdown]
# <p style="font-size:135%">Источники</p>
#
# 1. Астахова И.Ф., Мельников В.М., Толстобров А.П., Фертиков В.В. СУБД: язык SQL в примерах и задачах. — М.: ФИЗМАТЛИТ, 2009. — 168 с. — ISBN 978-5-9221-0816-4
# 2. Официальный сайт SQLite. https://sqlite.org/
# 3. Учебный ресурс SQLAlchemy Tutorial. https://www.tutorialspoint.com/sqlalchemy/index.htm
# 4. Официальный сайт SQLAlchemy. https://www.sqlalchemy.org/
# 5. SQLite — не игрушка. https://habr.com/ru/post/547448/
# 6. SQL for Data Science. https://medium.com/analytics-vidhya/sql-for-data-science-259298a10b0d
